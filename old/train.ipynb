# %%
"""
Created on Thu Sep 14 10:16:59 2023

@author: 51027
"""
import torch.nn as nn
import torch
import pandas as pd
import numpy as np
from preprocess import behavioral_embedding_model,text_embedding,preprocess_data,text_embedding_direct
from Data_loader import create_data_loaders
from model import TextDecisionModel
import matplotlib.pyplot as plt
from preprocess import behavioral_embedding,get_embeddings,option_prompt_generate

# %%
class CosineContrastiveLoss(nn.Module):
    def __init__(self, margin=0.9):
        super(CosineContrastiveLoss, self).__init__()
        self.margin = margin

    def forward(self, output1, output2, label):
        # Cosine similarity
        cosine_sim = nn.functional.cosine_similarity(output1, output2)
        
        # For similar pairs: we want the negative of (1 - cosine_sim) to make it closer to 1
        # For dissimilar pairs: we take max(0, cosine_sim - margin) to push them apart until a certain margin
        loss_contrastive = torch.mean(torch.mean((label) * torch.pow(1 - cosine_sim, 2)) +
                                      torch.mean((1-label) * torch.pow(torch.clamp(cosine_sim - self.margin, min=0.0), 2)))
        return loss_contrastive

# %%
class FeatureLoss(nn.Module):
    def __init__(self):
        super(FeatureLoss, self).__init__()
        
    
    def forward(self, output1, output2):
        # Standardize each dimension
        # std1 = torch.std(output1, dim=0, keepdim=True) + 1e-8  # Avoid division by zero
        # mean1 = torch.mean(output1, dim=0, keepdim=True)
        # output1 = (output1 - mean1) / std1
        
        # std2 = torch.std(output2, dim=0, keepdim=True) + 1e-8  # Avoid division by zero
        # mean2 = torch.mean(output2, dim=0, keepdim=True)
        # output2 = (output2 - mean2) / std2
        
        feature_loss = torch.square(output1 - output2)
        return feature_loss

# %%
c13k_problems = pd.read_json("data/c13k_problems_test.json", orient='index')
behavioral_embeddings = behavioral_embedding_model(c13k_problems)
c13k_problems_prepro = preprocess_data(c13k_problems)
# pool = multiprocessing.Pool(processes=4)
# text_problem_embeddings = pool.starmap(text_embedding_multiple, c13k_problems_prepro)
text_problem_embeddings_1 = text_embedding(c13k_problems_prepro,query = 'online')
# Out:
# ====开始时间为： 1709880087.314621 ====
# ====Processing No.  0 data====
# ====Processing No.  1 data====
# ====Processing No.  2 data====
# ====Processing No.  3 data====
# ====Processing No.  4 data====
# ====Processing No.  5 data====
# ====Processing No.  6 data====
# ====Processing No.  7 data====
# ====Processing No.  8 data====
# ====Processing No.  9 data====
# ====结束时间为： 1709880095.689111 ====
# ====用时： 8.374490022659302 ====

# %%
c13k_problems = pd.read_json("data/c13k_problems_test.json", orient='index')
behavioral_embeddings = behavioral_embedding_model(c13k_problems)
c13k_problems_prepro = preprocess_data(c13k_problems)
text_problem_embeddings_2 = text_embedding(c13k_problems_prepro,query = 'online')
# Out:
# ====开始时间为： 1709880097.799066 ====
# ====Processing No.  0 data====
# ====Processing No.  1 data====
# ====Processing No.  2 data====
# ====Processing No.  3 data====
# ====Processing No.  4 data====
# ====Processing No.  5 data====
# ====Processing No.  6 data====
# ====Processing No.  7 data====
# ====Processing No.  8 data====
# ====Processing No.  9 data====
# ====结束时间为： 1709880106.370038 ====
# ====用时： 8.570971965789795 ====

# %%
np.save('result/text_problem_embeddings_1.npy', text_problem_embeddings_1)
np.save('result/text_problem_embeddings_2.npy', text_problem_embeddings_2)

# %%
test1 = np.load('result/text_problem_embeddings_1.npy')
test2 = np.load('result/text_problem_embeddings_2.npy')

# %%
np.array_equal(text_problem_embeddings_1,text_problem_embeddings_2)
# Out:
# False

# %%
indices = np.where(text_problem_embeddings_1 != text_problem_embeddings_2)
for row, col in zip(indices[0], indices[1]):
            print(f"在位置 ({row + 1}, {col + 1})，值分别为：{text_problem_embeddings_1[row, col]} 和 {text_problem_embeddings_2[row, col]},差异为{text_problem_embeddings_1[row, col] - text_problem_embeddings_2[row, col]}")
# Out:
# 在位置 (8, 1)，值分别为：0.007737600244581699 和 0.007838011719286442,差异为-0.00010041147470474243
# 在位置 (8, 2)，值分别为：-0.02635827474296093 和 -0.02636120468378067,差异为2.9299408197402954e-06
# 在位置 (8, 3)，值分别为：-0.00692800572142005 和 -0.0068624080158770084,差异为-6.559770554304123e-05
# 在位置 (8, 4)，值分别为：-0.013199045322835445 和 -0.01316732820123434,差异为-3.1717121601104736e-05
# 在位置 (8, 5)，值分别为：-0.03429495543241501 和 -0.034325312823057175,差异为3.0357390642166138e-05
# 在位置 (8, 6)，值分别为：-0.014692150056362152 和 -0.014707056805491447,差异为1.4906749129295349e-05
# 在位置 (8, 7)，值分别为：-0.013471121899783611 和 -0.013512440025806427,差异为4.1318126022815704e-05
# 在位置 (8, 8)，值分别为：-0.028455257415771484 和 -0.02840532548725605,差异为-4.9931928515434265e-05
# 在位置 (8, 9)，值分别为：-0.0386747270822525 和 -0.038758669048547745,差异为8.394196629524231e-05
# 在位置 (8, 10)，值分别为：0.009496145881712437 和 0.009483927860856056,差异为1.2218020856380463e-05
# 在位置 (8, 11)，值分别为：-0.003663083538413048 和 -0.003699992783367634,差异为3.690924495458603e-05
# 在位置 (8, 12)，值分别为：0.04411626607179642 和 0.044041529297828674,差异为7.473677396774292e-05
# 在位置 (8, 13)，值分别为：-0.012283273972570896 和 -0.012284640222787857,差异为1.366250216960907e-06
# 在位置 (8, 14)，值分别为：-0.0025283237919211388 和 -0.00247882935218513,差异为-4.9494439736008644e-05
# 在位置 (8, 15)，值分别为：0.012104101479053497 和 0.01214526779949665,差异为-4.116632044315338e-05
# 在位置 (8, 16)，值分别为：0.012820792384445667 和 0.012862037867307663,差异为-4.12454828619957e-05
# 在位置 (8, 17)，值分别为：0.011161786504089832 和 0.011196210980415344,差异为-3.442447632551193e-05
# 在位置 (8, 18)，值分别为：-0.003009435487911105 和 -0.0029566758312284946,差异为-5.275965668261051e-05
# 在位置 (8, 19)，值分别为：0.0075584277510643005 和 0.007539357524365187,差异为1.9070226699113846e-05
# 在位置 (8, 20)，值分别为：-0.005750111769884825 和 -0.00576734310016036,差异为1.7231330275535583e-05
# 在位置 (8, 21)，值分别为：-0.01879321038722992 和 -0.018782027065753937,差异为-1.1183321475982666e-05
# 在位置 (8, 22)，值分别为：0.01106224674731493 和 0.011063476093113422,差异为-1.2293457984924316e-06
# 在位置 (8, 23)，值分别为：-0.00961559358984232 和 -0.00954365823417902,差异为-7.193535566329956e-05
# 在位置 (8, 24)，值分别为：-0.015807000920176506 和 -0.01579548418521881,差异为-1.1516734957695007e-05
# 在位置 (8, 25)，值分别为：-0.02829599194228649 和 -0.028246043249964714,差异为-4.9948692321777344e-05
# 在位置 (8, 26)，值分别为：0.006088548805564642 和 0.006148956716060638,差异为-6.0407910495996475e-05
# 在位置 (8, 27)，值分别为：0.024141842499375343 和 0.024157799780368805,差异为-1.595728099346161e-05
# 在位置 (8, 28)，值分别为：0.01929754763841629 和 0.019312966614961624,差异为-1.5418976545333862e-05
# 在位置 (8, 29)，值分别为：0.012568622827529907 和 0.012510289438068867,差异为5.83333894610405e-05
# 在位置 (8, 30)，值分别为：-0.010007118806242943 和 -0.010034779086709023,差异为2.7660280466079712e-05
# 在位置 (8, 31)，值分别为：0.03859509527683258 和 0.03865247964859009,差异为-5.7384371757507324e-05
# 在位置 (8, 32)，值分别为：-0.009356789290904999 和 -0.009357829578220844,差异为1.0402873158454895e-06
# 在位置 (8, 33)，值分别为：-0.04042663797736168 和 -0.04045768082141876,差异为3.104284405708313e-05
# 在位置 (8, 34)，值分别为：0.005524487234652042 和 0.005501872859895229,差异为2.261437475681305e-05
# 在位置 (8, 35)，值分别为：-0.0033213284332305193 和 -0.0033980202861130238,差异为7.669185288250446e-05
# 在位置 (8, 36)，值分别为：0.014838142320513725 和 0.014879612252116203,差异为-4.146993160247803e-05
# 在位置 (8, 37)，值分别为：0.01785089634358883 和 0.01785288006067276,差异为-1.9837170839309692e-06
# 在位置 (8, 38)，值分别为：0.02305353619158268 和 0.02308264560997486,差异为-2.9109418392181396e-05
# 在位置 (8, 39)，值分别为：0.006294265855103731 和 0.0062883286736905575,差异为5.9371814131736755e-06
# 在位置 (8, 40)，值分别为：-0.018063249066472054 和 -0.018065256997942924,差异为2.0079314708709717e-06
# 在位置 (8, 41)，值分别为：0.0024901668075472116 和 0.0024489639326930046,差异为4.120287485420704e-05
# 在位置 (8, 42)，值分别为：0.025747761130332947 和 0.025777170434594154,差异为-2.940930426120758e-05
# 在位置 (8, 43)，值分别为：0.009575777687132359 和 0.009596752934157848,差异为-2.0975247025489807e-05
# 在位置 (8, 44)，值分别为：0.001007845625281334 和 0.0010444598738104105,差异为-3.6614248529076576e-05
# 在位置 (8, 45)，值分别为：-0.009024987928569317 和 -0.009032628498971462,差异为7.640570402145386e-06
# 在位置 (8, 46)，值分别为：-0.001324715674854815 和 -0.0012991453986614943,差异为-2.557027619332075e-05
# 在位置 (8, 47)，值分别为：0.0031819718424230814 和 0.003169052070006728,差异为1.2919772416353226e-05
# 在位置 (8, 48)，值分别为：-0.01689530909061432 和 -0.016910459846258163,差异为1.5150755643844604e-05
# 在位置 (8, 49)，值分别为：-0.03379061818122864 和 -0.03379437327384949,差异为3.7550926208496094e-06
# 在位置 (8, 50)，值分别为：0.017585454508662224 和 0.017574137076735497,差异为1.1317431926727295e-05
# 在位置 (8, 51)，值分别为：-0.0028485117945820093 和 -0.0028305775485932827,差异为-1.7934245988726616e-05
# 在位置 (8, 52)，值分别为：0.018501225858926773 和 0.018397094681859016,差异为0.00010413117706775665
# 在位置 (8, 53)，值分别为：-0.03302083909511566 和 -0.03299796208739281,差异为-2.2877007722854614e-05
# 在位置 (8, 54)，值分别为：-0.003663083538413048 和 -0.0036502170842140913,差异为-1.286645419895649e-05
# 在位置 (8, 55)，值分别为：-0.023239344358444214 和 -0.023228654637932777,差异为-1.0689720511436462e-05
# 在位置 (8, 56)，值分别为：-0.00024242213112302125 和 -0.00021206517703831196,差异为-3.0356954084709287e-05
# 在位置 (8, 57)，值分别为：-0.00161587109323591 和 -0.0016533824382349849,差异为3.7511344999074936e-05
# 在位置 (8, 58)，值分别为：0.0003695434133987874 和 0.00036585130146704614,差异为3.6921119317412376e-06
# 在位置 (8, 59)，值分别为：-0.020054055377840996 和 -0.020029736682772636,差异为-2.4318695068359375e-05
# 在位置 (8, 60)，值分别为：0.005706977564841509 和 0.005694338586181402,差异为1.2638978660106659e-05
# 在位置 (8, 61)，值分别为：-0.008965264074504375 和 -0.008946350775659084,差异为-1.8913298845291138e-05
# 在位置 (8, 62)，值分别为：-0.012575259432196617 和 -0.012523562647402287,差异为-5.16967847943306e-05
# 在位置 (8, 63)，值分别为：-0.020983098074793816 和 -0.020972156897187233,差异为-1.0941177606582642e-05
# 在位置 (8, 64)，值分别为：-0.002299381187185645 和 -0.0022929999977350235,差异为-6.381189450621605e-06
# 在位置 (8, 65)，值分别为：-0.027074964717030525 和 -0.027091247960925102,差异为1.6283243894577026e-05
# 在位置 (8, 66)，值分别为：0.0016540281940251589 和 0.0016658263048157096,差异为-1.1798110790550709e-05
# 在位置 (8, 67)，值分别为：0.001342135132290423 和 0.0012659616768360138,差异为7.617345545440912e-05
# 在位置 (8, 68)，值分别为：-0.010683992877602577 和 -0.010658633895218372,差异为-2.5358982384204865e-05
# 在位置 (8, 69)，值分别为：-0.0015884974272921681 和 -0.0015488534700125456,差异为-3.9643957279622555e-05
# 在位置 (8, 70)，值分别为：0.0393914170563221 和 0.03942234441637993,差异为-3.092736005783081e-05
# 在位置 (8, 71)，值分别为：0.012907059863209724 和 0.012908495031297207,差异为-1.4351680874824524e-06
# 在位置 (8, 72)，值分别为：0.009383332915604115 和 0.009371102787554264,差异为1.2230128049850464e-05
# 在位置 (8, 73)，值分别为：-0.007691148202866316 和 -0.007705276366323233,差异为1.4128163456916809e-05
# 在位置 (8, 74)，值分别为：-0.013564025983214378 和 -0.013578807935118675,差异为1.4781951904296875e-05
# 在位置 (8, 75)，值分别为：0.023425152525305748 和 0.023387936875224113,差异为3.721565008163452e-05
# 在位置 (8, 76)，值分别为：0.020876921713352203 和 0.020879242569208145,差异为-2.3208558559417725e-06
# 在位置 (8, 77)，值分别为：-0.004572218284010887 和 -0.004579363390803337,差异为7.145106792449951e-06
# 在位置 (8, 78)，值分别为：0.004130922723561525 和 0.004108153283596039,差异为2.2769439965486526e-05
# 在位置 (8, 79)，值分别为：0.0010576158529147506 和 0.0011041907127946615,差异为-4.6574859879910946e-05
# 在位置 (8, 80)，值分别为：0.004203919321298599 和 0.004204386379569769,差异为-4.670582711696625e-07
# 在位置 (8, 81)，值分别为：0.02489835023880005 和 0.024901118129491806,差异为-2.767890691757202e-06
# 在位置 (8, 82)，值分别为：-0.019536444917321205 和 -0.01952534355223179,差异为-1.1101365089416504e-05
# 在位置 (8, 83)，值分别为：-0.007644695695489645 和 -0.007658819202333689,差异为1.4123506844043732e-05
# 在位置 (8, 84)，值分别为：-0.008208757266402245 和 -0.008169849403202534,差异为-3.8907863199710846e-05
# 在位置 (8, 85)，值分别为：0.027658933773636818 和 0.02763546258211136,差异为2.347119152545929e-05
# 在位置 (8, 86)，值分别为：-0.007538519334048033 和 -0.00752608384937048,差异为-1.2435484677553177e-05
# 在位置 (8, 87)，值分别为：0.0012027787743136287 和 0.0012609841069206595,差异为-5.820533260703087e-05
# 在位置 (8, 88)，值分别为：0.014293988235294819 和 0.014269030652940273,差异为2.4957582354545593e-05
# 在位置 (8, 89)，值分别为：-0.03899325802922249 和 -0.0389975905418396,差异为4.332512617111206e-06
# 在位置 (8, 90)，值分别为：-0.017970344051718712 和 -0.017972340807318687,差异为1.996755599975586e-06
# 在位置 (8, 91)，值分别为：0.03888707980513573 和 0.03889140486717224,差异为-4.325062036514282e-06
# 在位置 (8, 92)，值分别为：0.008699823170900345 和 0.008641059510409832,差异为5.876366049051285e-05
# 在位置 (8, 93)，值分别为：0.0003931842220481485 和 0.0004471516003832221,差异为-5.396737833507359e-05
# 在位置 (8, 94)，值分别为：0.024566547945141792 和 0.024582553654909134,差异为-1.6005709767341614e-05
# 在位置 (8, 95)，值分别为：-0.0030343204271048307 和 -0.002969949273392558,差异为-6.437115371227264e-05
# 在位置 (8, 96)，值分别为：0.019974421709775925 和 0.019976641982793808,差异为-2.2202730178833008e-06
# 在位置 (8, 97)，值分别为：-0.023398609831929207 和 -0.023414483293890953,差异为1.5873461961746216e-05
# 在位置 (8, 98)，值分别为：0.02069111168384552 和 0.0206801388412714,差异为1.0972842574119568e-05
# 在位置 (8, 99)，值分别为：0.017704904079437256 和 0.017733419314026833,差异为-2.851523458957672e-05
# 在位置 (8, 100)，值分别为：-0.020903464406728745 和 -0.020945608615875244,差异为4.2144209146499634e-05
# 在位置 (8, 101)，值分别为：-0.0012044378090649843 和 -0.001185490982607007,差异为-1.8946826457977295e-05
# 在位置 (8, 102)，值分别为：-0.010246016085147858 和 -0.010300248861312866,差异为5.4232776165008545e-05
# 在位置 (8, 103)，值分别为：-0.019868245348334312 和 -0.0198704544454813,差异为2.209097146987915e-06
# 在位置 (8, 104)，值分别为：5.7093106988759246e-06 和 3.80576602765359e-05,差异为-3.2348350941902027e-05
# 在位置 (8, 105)，值分别为：-0.012190369889140129 和 -0.012218272313475609,差异为2.7902424335479736e-05
# 在位置 (8, 106)，值分别为：-0.0009190888376906514 和 -0.0009100654860958457,差异为-9.023351594805717e-06
# 在位置 (8, 107)，值分别为：0.01412145234644413 和 0.014123021624982357,差异为-1.5692785382270813e-06
# 在位置 (8, 108)，值分别为：0.0031272247433662415 和 0.003177348058670759,差异为-5.0123315304517746e-05
# 在位置 (8, 109)，值分别为：0.002165001817047596 和 0.002195107750594616,差异为-3.010593354701996e-05
# 在位置 (8, 110)，值分别为：-0.006486710160970688 和 -0.0064907497726380825,差异为4.039611667394638e-06
# 在位置 (8, 111)，值分别为：-0.020465487614274025 和 -0.020454488694667816,差异为-1.0998919606208801e-05
# 在位置 (8, 112)，值分别为：-0.011832024902105331 和 -0.011859887279570103,差异为2.786237746477127e-05
# 在位置 (8, 113)，值分别为：0.001313932123593986 和 0.001245221821591258,差异为6.871030200272799e-05
# 在位置 (8, 114)，值分别为：-0.04098406434059143 和 -0.04093552753329277,差异为-4.853680729866028e-05
# 在位置 (8, 115)，值分别为：0.0022346798796206713 和 0.002254838589578867,差异为-2.0158709958195686e-05
# 在位置 (8, 116)，值分别为：0.016271522268652916 和 0.0162600576877594,差异为1.146458089351654e-05
# 在位置 (8, 117)，值分别为：0.0007623129058629274 和 0.0007939222268760204,差异为-3.1609321013092995e-05
# 在位置 (8, 118)，值分别为：0.007465523201972246 和 0.0074265324510633945,差异为3.8990750908851624e-05
# 在位置 (8, 119)，值分别为：-0.007803960237652063 和 -0.007871195673942566,差异为6.723543629050255e-05
# 在位置 (8, 120)，值分别为：-0.020983098074793816 和 -0.020958883687853813,差异为-2.421438694000244e-05
# 在位置 (8, 121)，值分别为：0.02533632703125477 和 0.025392238050699234,差异为-5.591101944446564e-05
# 在位置 (8, 122)，值分别为：0.0021517297718673944 和 0.0021702200174331665,差异为-1.8490245565772057e-05
# 在位置 (8, 123)，值分别为：0.03904634714126587 和 0.03902414068579674,差异为2.220645546913147e-05
# 在位置 (8, 124)，值分别为：-0.003775895806029439 和 -0.0038294096011668444,差异为5.3513795137405396e-05
# 在位置 (8, 125)，值分别为：0.016629867255687714 和 0.0166317168623209,差异为-1.8496066331863403e-06
# 在位置 (8, 126)，值分别为：0.015793729573488235 和 0.01586185209453106,差异为-6.812252104282379e-05
# 在位置 (8, 127)，值分别为：-0.0010849894024431705 和 -0.0011008722940459847,差异为1.5882891602814198e-05
# 在位置 (8, 128)，值分别为：-0.007445615250617266 和 -0.007506173569709063,差异为6.0558319091796875e-05
# 在位置 (8, 129)，值分别为：-0.0005093145882710814 和 -0.0005151783698238432,差异为5.863781552761793e-06
# 在位置 (8, 130)，值分别为：0.016191890463232994 和 0.01619368977844715,差异为-1.7993152141571045e-06
# 在位置 (8, 131)，值分别为：0.020120413973927498 和 0.020096104592084885,差异为2.430938184261322e-05
# 在位置 (8, 132)，值分别为：0.0065895686857402325 和 0.006663305219262838,差异为-7.37365335226059e-05
# 在位置 (8, 133)，值分别为：0.007492067292332649 和 0.007453079801052809,差异为3.898749127984047e-05
# 在位置 (8, 134)，值分别为：0.010232743807137012 和 0.010187423788011074,差异为4.5320019125938416e-05
# 在位置 (8, 135)，值分别为：-0.02308008074760437 和 -0.02308264560997486,差异为2.564862370491028e-06
# 在位置 (8, 136)，值分别为：0.034560397267341614 和 0.03453769162297249,差异为2.2705644369125366e-05
# 在位置 (8, 137)，值分别为：-0.044939130544662476 和 -0.04491757974028587,差异为-2.1550804376602173e-05
# 在位置 (8, 138)，值分别为：0.0016241660341620445 和 0.0015455351676791906,差异为7.863086648285389e-05
# 在位置 (8, 139)，值分别为：-0.014652334153652191 和 -0.014653962105512619,差异为1.6279518604278564e-06
# 在位置 (8, 140)，值分别为：0.003905298188328743 和 0.003922324161976576,差异为-1.702597364783287e-05
# 在位置 (8, 141)，值分别为：0.007458887062966824 和 0.007399985566735268,差异为5.890149623155594e-05
# 在位置 (8, 142)，值分别为：0.016550235450267792 和 0.01656534895300865,差异为-1.5113502740859985e-05
# 在位置 (8, 143)，值分别为：0.0015445337630808353 和 0.0015140104806050658,差异为3.052328247576952e-05
# 在位置 (8, 144)，值分别为：0.012090830132365227 和 0.012098810635507107,差异为-7.980503141880035e-06
# 在位置 (8, 145)，值分别为：-0.004625306464731693 和 -0.004632457159459591,差异为7.150694727897644e-06
# 在位置 (8, 146)，值分别为：0.03140164911746979 和 0.03132550045847893,差异为7.614865899085999e-05
# 在位置 (8, 147)，值分别为：0.008587011136114597 和 0.008607875555753708,差异为-2.0864419639110565e-05
# 在位置 (8, 148)，值分别为：0.004293505568057299 和 0.004293982870876789,差异为-4.773028194904327e-07
# 在位置 (8, 149)，值分别为：-0.006981093902140856 和 -0.006975233089178801,差异为-5.860812962055206e-06
# 在位置 (8, 150)，值分别为：-0.024340923875570297 和 -0.02435690350830555,差异为1.597963273525238e-05
# 在位置 (8, 151)，值分别为：-0.006632702890783548 和 -0.006603574380278587,差异为-2.9128510504961014e-05
# 在位置 (8, 152)，值分别为：0.0014516295632347465 和 0.0014741899212822318,差异为-2.256035804748535e-05
# 在位置 (8, 153)，值分别为：0.02534959837794304 和 0.025352416560053825,差异为-2.818182110786438e-06
# 在位置 (8, 154)，值分别为：0.011639580130577087 和 0.011574506759643555,差异为6.507337093353271e-05
# 在位置 (8, 155)，值分别为：4.287491537979804e-05 和 9.550710092298687e-05,差异为-5.2632185543188825e-05
# 在位置 (8, 156)，值分别为：0.0056439354084432125 和 0.005594787187874317,差异为4.914822056889534e-05
# 在位置 (8, 157)，值分别为：0.00425368919968605 和 0.004244206938892603,差异为9.482260793447495e-06
# 在位置 (8, 158)，值分别为：0.019908061251044273 和 0.01988372765481472,差异为2.4333596229553223e-05
# 在位置 (8, 159)，值分别为：0.00551785109564662 和 0.005462052300572395,差异为5.579879507422447e-05
# 在位置 (8, 160)，值分别为：-0.01782435178756714 和 -0.0178794264793396,差异为5.507469177246094e-05
# 在位置 (8, 161)，值分别为：-0.02631845884025097 和 -0.02633465640246868,差异为1.6197562217712402e-05
# 在位置 (8, 162)，值分别为：-0.0015146717196330428 和 -0.0015413871733471751,差异为2.671545371413231e-05
# 在位置 (8, 163)，值分别为：-0.0061648632399737835 和 -0.0061887772753834724,差异为2.391403540968895e-05
# 在位置 (8, 164)，值分别为：-0.012542079202830791 和 -0.012510289438068867,差异为-3.1789764761924744e-05
# 在位置 (8, 165)，值分别为：0.010186291299760342 和 0.010187423788011074,差异为-1.1324882507324219e-06
# 在位置 (8, 166)，值分别为：0.03182635456323624 和 0.031803347170352936,差异为2.300739288330078e-05
# 在位置 (8, 167)，值分别为：0.01935063675045967 和 0.019352788105607033,差异为-2.1513551473617554e-06
# 在位置 (8, 168)，值分别为：0.004602080211043358 和 0.004652367439121008,差异为-5.028722807765007e-05
# 在位置 (8, 169)，值分别为：-0.0066857910715043545 和 -0.006726354826241732,差异为4.056375473737717e-05
# 在位置 (8, 170)，值分别为：-0.009449693374335766 和 -0.00951047521084547,差异为6.078183650970459e-05
# 在位置 (8, 171)，值分别为：-0.015461928211152554 和 -0.0154503732919693,差异为-1.1554919183254242e-05
# 在位置 (8, 172)，值分别为：0.007969860918819904 和 0.008023841306567192,差异为-5.398038774728775e-05
# 在位置 (8, 173)，值分别为：-0.012568622827529907 和 -0.012616477906703949,差异为4.785507917404175e-05
# 在位置 (8, 174)，值分别为：0.02069111168384552 和 0.02064031921327114,差异为5.079247057437897e-05
# 在位置 (8, 175)，值分别为：0.029888637363910675 和 0.02997160144150257,差异为-8.296407759189606e-05
# 在位置 (8, 176)，值分别为：0.025190334767103195 和 0.025232955813407898,差异为-4.262104630470276e-05
# 在位置 (8, 177)，值分别为：-0.001427573966793716 和 -0.00141611834987998,差异为-1.1455616913735867e-05
# 在位置 (8, 178)，值分别为：-0.01152676809579134 和 -0.011561233550310135,差异为3.4465454518795013e-05
# 在位置 (8, 179)，值分别为：-0.008115853182971478 和 -0.00812339223921299,差异为7.539056241512299e-06
# 在位置 (8, 180)，值分别为：-0.021912140771746635 和 -0.02187475562095642,差异为-3.738515079021454e-05
# 在位置 (8, 181)，值分别为：-0.005405039060860872 和 -0.005382411181926727,差异为-2.2627878934144974e-05
# 在位置 (8, 182)，值分别为：-0.0010036980966106057 和 -0.0010635405778884888,差异为5.984248127788305e-05
# 在位置 (8, 183)，值分别为：0.009781494736671448 和 0.009789218194782734,差异为-7.723458111286163e-06
# 在位置 (8, 184)，值分别为：0.0017834305763244629 和 0.001798561541363597,差异为-1.5130965039134026e-05
# 在位置 (8, 185)，值分别为：0.0017967026215046644 和 0.00177865126170218,差异为1.8051359802484512e-05
# 在位置 (8, 186)，值分别为：-0.012873880565166473 和 -0.012868674471974373,差异为-5.206093192100525e-06
# 在位置 (8, 187)，值分别为：0.017213838174939156 和 0.017268845811486244,差异为-5.500763654708862e-05
# 在位置 (8, 188)，值分别为：-0.019456813111901283 和 -0.0194987952709198,差异为4.198215901851654e-05
# 在位置 (8, 189)，值分别为：0.013557390309870243 和 0.013459346257150173,差异为9.804405272006989e-05
# 在位置 (8, 190)，值分别为：0.004831023048609495 和 0.00486806221306324,差异为-3.703916445374489e-05
# 在位置 (8, 191)，值分别为：0.017147477716207504 和 0.017122836783528328,差异为2.464093267917633e-05
# 在位置 (8, 192)，值分别为：0.03142819553613663 和 0.031458236277103424,差异为-3.0040740966796875e-05
# 在位置 (8, 193)，值分别为：-0.001012822613120079 和 -0.001008787308819592,差异为-4.0353043004870415e-06
# 在位置 (8, 194)，值分别为：0.012608439661562443 和 0.012609841302037239,差异为-1.4016404747962952e-06
# 在位置 (8, 195)，值分别为：-0.658717930316925 和 -0.658791184425354,差异为7.325410842895508e-05
# 在位置 (8, 196)，值分别为：-0.026570627465844154 和 -0.026493938639760017,差异为-7.668882608413696e-05
# 在位置 (8, 197)，值分别为：-0.019987694919109344 和 -0.019963368773460388,差异为-2.43261456489563e-05
# 在位置 (8, 198)，值分别为：0.005239138379693031 和 0.005193263292312622,差异为4.587508738040924e-05
# 在位置 (8, 199)，值分别为：-0.011022429913282394 和 -0.011010382324457169,差异为-1.204758882522583e-05
# 在位置 (8, 200)，值分别为：0.007120450027287006 和 0.007194246165454388,差异为-7.379613816738129e-05
# 在位置 (8, 201)，值分别为：-0.0023640822619199753 和 -0.002351071685552597,差异为-1.3010576367378235e-05
# 在位置 (8, 202)，值分别为：0.007930045016109943 和 0.00792428944259882,差异为5.755573511123657e-06
# 在位置 (8, 203)，值分别为：-0.039709948003292084 和 -0.03976745530962944,差异为5.750730633735657e-05
# 在位置 (8, 204)，值分别为：0.02493816614151001 和 0.024980759248137474,差异为-4.2593106627464294e-05
# 在位置 (8, 205)，值分别为：0.00824857410043478 和 0.00831585843116045,差异为-6.728433072566986e-05
# 在位置 (8, 206)，值分别为：-0.004313413519412279 和 -0.004290664102882147,差异为-2.2749416530132294e-05
# 在位置 (8, 207)，值分别为：-0.026583898812532425 和 -0.026600128039717674,差异为1.622922718524933e-05
# 在位置 (8, 208)，值分别为：-0.013882555067539215 和 -0.013870825059711933,差异为-1.1730007827281952e-05
# 在位置 (8, 209)，值分别为：-0.008454290218651295 和 -0.008481777273118496,差异为2.7487054467201233e-05
# 在位置 (8, 210)，值分别为：-0.017306741327047348 和 -0.017321938648819923,差异为1.5197321772575378e-05
# 在位置 (8, 211)，值分别为：0.01745273359119892 和 0.01740157976746559,差异为5.115382373332977e-05
# 在位置 (8, 212)，值分别为：0.018474681302905083 和 0.018476735800504684,差异为-2.0544975996017456e-06
# 在位置 (8, 213)，值分别为：-0.03660428896546364 和 -0.03658181056380272,差异为-2.247840166091919e-05
# 在位置 (8, 214)，值分别为：-0.003145473776385188 和 -0.003200576640665531,差异为5.5102864280343056e-05
# 在位置 (8, 215)，值分别为：-0.02500452660024166 和 -0.025060400366783142,差异为5.587376654148102e-05
# 在位置 (8, 216)，值分别为：0.0220846775919199 和 0.022100405767560005,差异为-1.57281756401062e-05
# 在位置 (8, 217)，值分别为：-0.008746275678277016 和 -0.008800341747701168,差异为5.4066069424152374e-05
# 在位置 (8, 218)，值分别为：0.0024486915208399296 和 0.002498739631846547,差异为-5.0048111006617546e-05
# 在位置 (8, 219)，值分别为：0.00011550823546713218 和 6.937486614333466e-05,差异为4.6133369323797524e-05
# 在位置 (8, 220)，值分别为：-0.016165345907211304 和 -0.016153870150446892,差异为-1.1475756764411926e-05
# 在位置 (8, 221)，值分别为：0.0027556074783205986 和 0.0028687387239187956,差异为-0.00011313124559819698
# 在位置 (8, 222)，值分别为：-0.019894789904356003 和 -0.01983063481748104,差异为-6.415508687496185e-05
# 在位置 (8, 223)，值分别为：-0.008387929759919643 和 -0.008368952199816704,差异为-1.8977560102939606e-05
# 在位置 (8, 224)，值分别为：-0.0075982436537742615 和 -0.007599088363349438,差异为8.44709575176239e-07
# 在位置 (8, 225)，值分别为：-0.005371858831495047 和 -0.005332635249942541,差异为-3.922358155250549e-05
# 在位置 (8, 226)，值分别为：0.01779780723154545 和 0.01783960685133934,差异为-4.179961979389191e-05
# 在位置 (8, 227)，值分别为：0.0033760755322873592 和 0.003371473168954253,差异为4.602363333106041e-06
# 在位置 (8, 228)，值分别为：0.021553795784711838 和 0.021596012637019157,差异为-4.221685230731964e-05
# 在位置 (8, 229)，值分别为：0.02168651483952999 和 0.021742019802331924,差异为-5.550496280193329e-05
# 在位置 (8, 230)，值分别为：-0.0023873085156083107 和 -0.0024157799780368805,差异为2.8471462428569794e-05
# 在位置 (8, 231)，值分别为：0.0027655616868287325 和 0.002747617894783616,差异为1.7943792045116425e-05
# 在位置 (8, 232)，值分别为：0.02205813303589821 和 0.022047311067581177,差异为1.082196831703186e-05
# 在位置 (8, 233)，值分别为：0.017572183161973953 和 0.017600683495402336,差异为-2.8500333428382874e-05
# 在位置 (8, 234)，值分别为：0.028481800109148026 和 0.028511514887213707,差异为-2.9714778065681458e-05
# 在位置 (8, 235)，值分别为：-0.016682956367731094 和 -0.01665826328098774,差异为-2.4693086743354797e-05
# 在位置 (8, 236)，值分别为：0.0032665811013430357 和 0.0032818769104778767,差异为-1.5295809134840965e-05
# 在位置 (8, 237)，值分别为：-0.00034859846346080303 和 -0.0003610811254475266,差异为1.2482661986723542e-05
# 在位置 (8, 238)，值分别为：-0.0053851306438446045 和 -0.005312724970281124,差异为-7.240567356348038e-05
# 在位置 (8, 239)，值分别为：-0.004658486694097519 和 -0.004652367439121008,差异为-6.119254976511002e-06
# 在位置 (8, 240)，值分别为：-0.002244634088128805 和 -0.0023129102773964405,差异为6.827618926763535e-05
# 在位置 (8, 241)，值分别为：0.010756989941000938 和 0.01072500180453062,差异为3.198813647031784e-05
# 在位置 (8, 242)，值分别为：0.010465004481375217 和 0.010432983748614788,差异为3.202073276042938e-05
# 在位置 (8, 243)，值分别为：0.0011173399398103356 和 0.0011788542615249753,差异为-6.151432171463966e-05
# 在位置 (8, 244)，值分别为：-0.02165997214615345 和 -0.021635832265019417,差异为-2.4139881134033203e-05
# 在位置 (8, 245)，值分别为：-0.003689627395942807 和 -0.0036867193412035704,差异为-2.9080547392368317e-06
# 在位置 (8, 246)，值分别为：-0.006221269257366657 和 -0.0062850103713572025,差异为6.374111399054527e-05
# 在位置 (8, 247)，值分别为：-0.01033228449523449 和 -0.010359980165958405,差异为2.76956707239151e-05
# 在位置 (8, 248)，值分别为：-0.020890193060040474 和 -0.020892515778541565,差异为2.3227185010910034e-06
# 在位置 (8, 249)，值分别为：0.02499125339090824 和 0.025020578876137733,差异为-2.9325485229492188e-05
# 在位置 (8, 250)，值分别为：0.005803199950605631 和 0.005777298007160425,差异为2.590194344520569e-05
# 在位置 (8, 251)，值分别为：0.025309782475233078 和 0.025339143350720406,差异为-2.9360875487327576e-05
# 在位置 (8, 252)，值分别为：-0.019868245348334312 和 -0.01984390802681446,差异为-2.4337321519851685e-05
# 在位置 (8, 253)，值分别为：0.0005080703413113952 和 0.0005408957949839532,差异为-3.282545367255807e-05
# 在位置 (8, 254)，值分别为：-0.009542597457766533 和 -0.009470654651522636,差异为-7.194280624389648e-05
# 在位置 (8, 255)，值分别为：-0.007863684557378292 和 -0.0079110162332654,差异为4.733167588710785e-05
# 在位置 (8, 256)，值分别为：-0.026650259271264076 和 -0.026573579758405685,差异为-7.667951285839081e-05
# 在位置 (8, 257)，值分别为：-0.029915181919932365 和 -0.03002469427883625,差异为0.00010951235890388489
# 在位置 (8, 258)，值分别为：-0.023199528455734253 和 -0.02313574030995369,差异为-6.378814578056335e-05
# 在位置 (8, 259)，值分别为：0.003935160115361214 和 0.003965463023632765,差异为-3.0302908271551132e-05
# 在位置 (8, 260)，值分别为：-0.003971658181399107 和 -0.003952189814299345,差异为-1.9468367099761963e-05
# 在位置 (8, 261)，值分别为：-0.006340717896819115 和 -0.0063447412103414536,差异为4.023313522338867e-06
# 在位置 (8, 262)，值分别为：0.0010634222999215126 和 0.0010560741648077965,差异为7.3481351137161255e-06
# 在位置 (8, 263)，值分别为：0.027658933773636818 和 0.027662009000778198,差异为-3.07522714138031e-06
# 在位置 (8, 264)，值分别为：-0.004263643175363541 和 -0.004290664102882147,差异为2.7020927518606186e-05
# 在位置 (8, 265)，值分别为：-0.015661008656024933 和 -0.01562292966991663,差异为-3.807898610830307e-05
# 在位置 (8, 266)，值分别为：0.00566384382545948 和 0.005687701981514692,差异为-2.385815605521202e-05
# 在位置 (8, 267)，值分别为：0.0006868281634524465 和 0.0007039111806079745,差异为-1.708301715552807e-05
# 在位置 (8, 268)，值分别为：0.00800304114818573 和 0.00792428944259882,差异为7.875170558691025e-05
# 在位置 (8, 269)，值分别为：0.010949433781206608 和 0.010983834974467754,差异为-3.4401193261146545e-05
# 在位置 (8, 270)，值分别为：-0.010378736071288586 和 -0.010466167703270912,差异为8.743163198232651e-05
# 在位置 (8, 271)，值分别为：0.02736694924533367 和 0.027290349826216698,差异为7.659941911697388e-05
# 在位置 (8, 272)，值分别为：-0.04754045233130455 和 -0.04749264195561409,差异为-4.7810375690460205e-05
# 在位置 (8, 273)，值分别为：-0.029994813725352287 和 -0.029918506741523743,差异为-7.630698382854462e-05
# 在位置 (8, 274)，值分别为：0.011619672179222107 和 0.011567870154976845,差异为5.1802024245262146e-05
# 在位置 (8, 275)，值分别为：0.007764144334942102 和 0.007791554555296898,差异为-2.7410220354795456e-05
# 在位置 (8, 276)，值分别为：-0.020492032170295715 和 -0.020481036975979805,差异为-1.099519431591034e-05
# 在位置 (8, 277)，值分别为：-0.020558392629027367 和 -0.020547404885292053,差异为-1.0987743735313416e-05
# 在位置 (8, 278)，值分别为：-0.003961704205721617 和 -0.00396214472129941,差异为4.4051557779312134e-07
# 在位置 (8, 279)，值分别为：0.012628347612917423 和 0.012676208280026913,差异为-4.786066710948944e-05
# 在位置 (8, 280)，值分别为：-0.011818752624094486 和 -0.011806793510913849,差异为-1.195911318063736e-05
# 在位置 (8, 281)，值分别为：0.007850412279367447 和 0.007804827764630318,差异为4.558451473712921e-05
# 在位置 (8, 282)，值分别为：-0.007664604112505913 和 -0.007678729481995106,差异为1.4125369489192963e-05
# 在位置 (8, 283)，值分别为：-0.017240380868315697 和 -0.017242297530174255,差异为1.9166618585586548e-06
# 在位置 (8, 284)，值分别为：-0.0025880481116473675 和 -0.0026115644723176956,差异为2.351636067032814e-05
# 在位置 (8, 285)，值分别为：-0.0038953442126512527 和 -0.003922324161976576,差异为2.6979949325323105e-05
# 在位置 (8, 286)，值分别为：0.028428712859749794 和 0.028538061305880547,差异为-0.00010934844613075256
# 在位置 (8, 287)，值分别为：-0.0028684199787676334 和 -0.0028687387239187956,差异为3.187451511621475e-07
# 在位置 (8, 288)，值分别为：-0.007286350708454847 和 -0.0073867118917405605,差异为0.0001003611832857132
# 在位置 (8, 289)，值分别为：0.0025731169153004885 和 0.002521968213841319,差异为5.114870145916939e-05
# 在位置 (8, 290)，值分别为：0.028455257415771484 和 0.028484966605901718,差异为-2.9709190130233765e-05
# 在位置 (8, 291)，值分别为：-0.007711056154221296 和 -0.007685366086661816,差异为-2.5690067559480667e-05
# 在位置 (8, 292)，值分别为：0.0011571560753509402 和 0.0011506479931995273,差异为6.508082151412964e-06
# 在位置 (8, 293)，值分别为：0.011652852408587933 和 0.011607690714299679,差异为4.5161694288253784e-05
# 在位置 (8, 294)，值分别为：-0.03158745914697647 和 -0.0315113291144371,差异为-7.613003253936768e-05
# 在位置 (8, 295)，值分别为：-0.01970898173749447 和 -0.019697898998856544,差异为-1.1082738637924194e-05
# 在位置 (8, 296)，值分别为：0.0015130126848816872 和 0.0014766787644475698,差异为3.633392043411732e-05
# 在位置 (8, 297)，值分别为：0.017718175426125526 和 0.017640503123402596,差异为7.767230272293091e-05
# 在位置 (8, 298)，值分别为：0.018992291763424873 和 0.019007675349712372,差异为-1.5383586287498474e-05
# 在位置 (8, 299)，值分别为：0.046770673245191574 和 0.04674932733178139,差异为2.1345913410186768e-05
# 在位置 (8, 300)，值分别为：0.01981515809893608 和 0.019777540117502213,差异为3.761798143386841e-05
# 在位置 (8, 301)，值分别为：-0.02821636013686657 和 -0.028219496831297874,差异为3.1366944313049316e-06
# 在位置 (8, 302)，值分别为：0.008175577037036419 和 0.008183123543858528,差异为-7.546506822109222e-06
# 在位置 (8, 303)，值分别为：0.03288811817765236 和 0.03289177641272545,差异为-3.6582350730895996e-06
# 在位置 (8, 304)，值分别为：-0.02589375339448452 和 -0.025816990062594414,差异为-7.67633318901062e-05
# 在位置 (8, 305)，值分别为：0.00824193749576807 和 0.008295947685837746,差异为-5.4010190069675446e-05
# 在位置 (8, 306)，值分别为：0.006075276993215084 和 0.0061058178544044495,差异为-3.054086118936539e-05
# 在位置 (8, 307)，值分别为：-0.014864685945212841 和 -0.01483979169279337,差异为-2.489425241947174e-05
# 在位置 (8, 308)，值分别为：0.012090830132365227 和 0.012125357985496521,差异为-3.452785313129425e-05
# 在位置 (8, 309)，值分别为：0.02119545079767704 和 0.021237626671791077,差异为-4.217587411403656e-05
# 在位置 (8, 310)，值分别为：-0.02629191428422928 和 -0.026308109983801842,差异为1.619569957256317e-05
# 在位置 (8, 311)，值分别为：0.02026640810072422 和 0.02026866003870964,差异为-2.251937985420227e-06
# 在位置 (8, 312)，值分别为：-0.007697783876210451 和 -0.007658819202333689,差异为-3.896467387676239e-05
# 在位置 (8, 313)，值分别为：0.005361904855817556 和 0.005412276368588209,差异为-5.037151277065277e-05
# 在位置 (8, 314)，值分别为：-0.02119545079767704 和 -0.021211080253124237,差异为1.562945544719696e-05
# 在位置 (8, 315)，值分别为：0.017598727717995644 和 0.017574137076735497,差异为2.4590641260147095e-05
# 在位置 (8, 316)，值分别为：0.02542923204600811 和 0.02551169879734516,差异为-8.246675133705139e-05
# 在位置 (8, 317)，值分别为：0.020505303516983986 和 0.020454488694667816,差异为5.081482231616974e-05
# 在位置 (8, 318)，值分别为：-0.02495143748819828 和 -0.024927664548158646,差异为-2.3772940039634705e-05
# 在位置 (8, 319)，值分别为：-0.007166902534663677 和 -0.007147789001464844,差异为-1.9113533198833466e-05
# 在位置 (8, 320)，值分别为：0.005461445078253746 和 0.005435504950582981,差异为2.5940127670764923e-05
# 在位置 (8, 321)，值分别为：0.00542826484888792 和 0.005379092879593372,差异为4.9171969294548035e-05
# 在位置 (8, 322)，值分别为：-0.01830214448273182 和 -0.018343999981880188,差异为4.1855499148368835e-05
# 在位置 (8, 323)，值分别为：0.008991807699203491 和 0.008966260589659214,差异为2.554710954427719e-05
# 在位置 (8, 324)，值分别为：-0.02534959837794304 和 -0.025352416560053825,差异为2.818182110786438e-06
# 在位置 (8, 325)，值分别为：0.0017120933625847101 和 0.0016990101430565119,差异为1.3083219528198242e-05
# 在位置 (8, 326)，值分别为：0.00610845722258091 和 0.00617882190272212,差异为-7.036468014121056e-05
# 在位置 (8, 327)，值分别为：-0.004854249302297831 和 -0.004914519377052784,差异为6.0270074754953384e-05
# 在位置 (8, 328)，值分别为：-0.010445096530020237 和 -0.010505988262593746,差异为6.0891732573509216e-05
# 在位置 (8, 329)，值分别为：0.0027506304904818535 和 0.0027310261502861977,差异为1.9604340195655823e-05
# 在位置 (8, 330)，值分别为：0.002835239749401808 和 0.0028820123989135027,差异为-4.677264951169491e-05
# 在位置 (8, 331)，值分别为：-0.007100542075932026 和 -0.00711460504680872,差异为1.4062970876693726e-05
# 在位置 (8, 332)，值分别为：-0.0211025457829237 和 -0.02113143913447857,差异为2.8893351554870605e-05
# 在位置 (8, 333)，值分别为：-0.0020604843739420176 和 -0.0020905788987874985,差异为3.009452484548092e-05
# 在位置 (8, 334)，值分别为：-0.032171428203582764 和 -0.032228097319602966,差异为5.666911602020264e-05
# 在位置 (8, 335)，值分别为：-0.025495590642094612 和 -0.025405511260032654,差异为-9.007938206195831e-05
# 在位置 (8, 336)，值分别为：0.0033959834836423397 和 0.0034212488681077957,差异为-2.526538446545601e-05
# 在位置 (8, 337)，值分别为：0.01603262685239315 和 0.015994587913155556,差异为3.8038939237594604e-05
# 在位置 (8, 338)，值分别为：-0.02545577473938465 和 -0.02549842558801174,差异为4.2650848627090454e-05
# 在位置 (8, 339)，值分别为：-0.013710019178688526 和 -0.013738090172410011,差异为2.8070993721485138e-05
# 在位置 (8, 340)，值分别为：-0.040692079812288284 和 -0.04064350947737694,差异为-4.8570334911346436e-05
# 在位置 (8, 341)，值分别为：-0.0024437145330011845 和 -0.0024406679440289736,差异为-3.046588972210884e-06
# 在位置 (8, 342)，值分别为：-0.0015661008656024933 和 -0.0015828668838366866,差异为1.6766018234193325e-05
# 在位置 (8, 343)，值分别为：0.0008983513107523322 和 0.0008652673568576574,差异为3.308395389467478e-05
# 在位置 (8, 344)，值分别为：0.011287870816886425 和 0.011275852099061012,差异为1.201871782541275e-05
# 在位置 (8, 345)，值分别为：0.020160231739282608 和 0.020215565338730812,差异为-5.533359944820404e-05
# 在位置 (8, 346)，值分别为：-0.012575259432196617 和 -0.012596567161381245,差异为2.1307729184627533e-05
# 在位置 (8, 347)，值分别为：0.004077834542840719 和 0.004038467537611723,差异为3.936700522899628e-05
# 在位置 (8, 348)，值分别为：-0.012197006493806839 和 -0.012118720449507236,差异为-7.828604429960251e-05
# 在位置 (8, 349)，值分别为：-0.01386928278952837 和 -0.013857551850378513,差异为-1.1730939149856567e-05
# 在位置 (8, 350)，值分别为：-0.0015204782830551267 和 -0.0015579790342599154,差异为3.7500751204788685e-05
# 在位置 (8, 351)，值分别为：-0.0038223478477448225 和 -0.0038294096011668444,差异为7.061753422021866e-06
# 在位置 (8, 352)，值分别为：0.015899905934929848 和 0.01583530567586422,差异为6.460025906562805e-05
# 在位置 (8, 353)，值分别为：-0.014665605500340462 和 -0.014587595127522945,差异为-7.801037281751633e-05
# 在位置 (8, 354)，值分别为：-0.011759028770029545 和 -0.011780246160924435,差异为2.121739089488983e-05
# 在位置 (8, 355)，值分别为：0.037480246275663376 和 0.037537503987550735,差异为-5.725771188735962e-05
# 在位置 (8, 356)，值分别为：0.013988731428980827 和 0.013990286737680435,差异为-1.5553086996078491e-06
# 在位置 (8, 357)，值分别为：-0.0060686408542096615 和 -0.006052723620086908,差异为-1.5917234122753143e-05
# 在位置 (8, 358)，值分别为：-0.022204125300049782 和 -0.022193320095539093,差异为-1.0805204510688782e-05
# 在位置 (8, 359)，值分别为：-0.017678359523415565 和 -0.017680324614048004,差异为1.9650906324386597e-06
# 在位置 (8, 360)，值分别为：-0.01528939139097929 和 -0.01523799728602171,差异为-5.1394104957580566e-05
# 在位置 (8, 361)，值分别为：-0.005726885981857777 和 -0.005697656888514757,差异为-2.9229093343019485e-05
# 在位置 (8, 362)，值分别为：0.01531593594700098 和 0.015344185754656792,差异为-2.824980765581131e-05
# 在位置 (8, 363)，值分别为：-0.007485431153327227 和 -0.00752608384937048,差异为4.0652696043252945e-05
# 在位置 (8, 364)，值分别为：-0.027897831052541733 和 -0.027847837656736374,差异为-4.999339580535889e-05
# 在位置 (8, 365)，值分别为：-0.004562264308333397 和 -0.004635775927454233,差异为7.351161912083626e-05
# 在位置 (8, 366)，值分别为：-0.02497798204421997 和 -0.025033852085471153,差异为5.5870041251182556e-05
# 在位置 (8, 367)，值分别为：0.013842739164829254 和 0.013844277709722519,差异为-1.5385448932647705e-06
# 在位置 (8, 368)，值分别为：0.016311338171362877 和 0.016286605969071388,差异为2.4732202291488647e-05
# 在位置 (8, 369)，值分别为：0.010285831987857819 和 0.01032015960663557,差异为-3.432761877775192e-05
# 在位置 (8, 370)，值分别为：0.028057094663381577 和 0.02798057347536087,差异为7.652118802070618e-05
# 在位置 (8, 371)，值分别为：-0.006815193220973015 和 -0.0068624080158770084,差异为4.7214794903993607e-05
# 在位置 (8, 372)，值分别为：-0.008056129328906536 和 -0.008037114515900612,差异为-1.9014813005924225e-05
# 在位置 (8, 373)，值分别为：0.009509417228400707 和 0.009556932374835014,差异为-4.75151464343071e-05
# 在位置 (8, 374)，值分别为：-0.010683992877602577 和 -0.01073827501386404,差异为5.4282136261463165e-05
# 在位置 (8, 375)，值分别为：0.011798844672739506 和 0.011846614070236683,差异为-4.7769397497177124e-05
# 在位置 (8, 376)，值分别为：0.008812635205686092 和 0.008813614957034588,差异为-9.797513484954834e-07
# 在位置 (8, 377)，值分别为：0.0010650813346728683 和 0.001100042718462646,差异为-3.4961383789777756e-05
# 在位置 (8, 378)，值分别为：-0.017160749062895775 和 -0.017162656411528587,差异为1.9073486328125e-06
# 在位置 (8, 379)，值分别为：0.031720180064439774 和 0.03175025060772896,差异为-3.007054328918457e-05
# 在位置 (8, 380)，值分别为：-0.01648387499153614 和 -0.016498981043696404,差异为1.5106052160263062e-05
# 在位置 (8, 381)，值分别为：0.02816327102482319 和 0.028192950412631035,差异为-2.967938780784607e-05
# 在位置 (8, 382)，值分别为：-0.0022711781784892082 和 -0.002243224298581481,差异为-2.795387990772724e-05
# 在位置 (8, 383)，值分别为：-0.03418877720832825 和 -0.034272219985723495,差异为8.344277739524841e-05
# 在位置 (8, 384)，值分别为：0.008805999532341957 和 0.008860072121024132,差异为-5.407258868217468e-05
# 在位置 (8, 385)，值分别为：-0.025203606113791466 和 -0.02516658790409565,差异为-3.701820969581604e-05
# 在位置 (8, 386)，值分别为：0.03424186632037163 和 0.034245673567056656,差异为-3.807246685028076e-06
# 在位置 (8, 387)，值分别为：0.00031085609225556254 和 0.00023436053015757352,差异为7.649556209798902e-05
# 在位置 (8, 388)，值分别为：-0.0062577673234045506 和 -0.006271736696362495,差异为1.396937295794487e-05
# 在位置 (8, 389)，值分别为：0.0041143326088786125 和 0.004084924701601267,差异为2.9407907277345657e-05
# 在位置 (8, 390)，值分别为：0.0018033386440947652 和 0.001818471821025014,差异为-1.5133176930248737e-05
# 在位置 (8, 391)，值分别为：0.02869415283203125 和 0.028697343543171883,差异为-3.1907111406326294e-06
# 在位置 (8, 392)，值分别为：0.002888327930122614 和 0.002898604143410921,差异为-1.027621328830719e-05
# 在位置 (8, 393)，值分别为：-0.005461445078253746 和 -0.005438823718577623,差异为-2.2621359676122665e-05
# 在位置 (8, 394)，值分别为：0.036524657160043716 和 0.03658181056380272,差异为-5.7153403759002686e-05
# 在位置 (8, 395)，值分别为：0.021527251228690147 和 0.02155619114637375,差异为-2.893991768360138e-05
# 在位置 (8, 396)，值分别为：0.01367020234465599 和 0.013658449053764343,差异为1.1753290891647339e-05
# 在位置 (8, 397)，值分别为：0.011712576262652874 和 0.01173378899693489,差异为-2.1212734282016754e-05
# 在位置 (8, 398)，值分别为：-0.015130126848816872 和 -0.015171629376709461,差异为4.150252789258957e-05
# 在位置 (8, 399)，值分别为：0.0022662009578198195 和 0.0022581571247428656,差异为8.043833076953888e-06
# 在位置 (8, 400)，值分别为：-0.02026640810072422 和 -0.02033502794802189,差异为6.861984729766846e-05
# 在位置 (8, 401)，值分别为：0.013550754636526108 和 0.013592081144452095,差异为-4.1326507925987244e-05
# 在位置 (8, 402)，值分别为：-0.02491162158548832 和 -0.024901118129491806,差异为-1.0503455996513367e-05
# 在位置 (8, 403)，值分别为：0.009363424964249134 和 0.009384375996887684,差异为-2.0951032638549805e-05
# 在位置 (8, 404)，值分别为：0.009184252470731735 和 0.009165363386273384,差异为1.8889084458351135e-05
# 在位置 (8, 405)，值分别为：-0.004923927132040262 和 -0.004924474749714136,差异为5.476176738739014e-07
# 在位置 (8, 406)，值分别为：-0.032702308148145676 和 -0.032679397612810135,差异为-2.291053533554077e-05
# 在位置 (8, 407)，值分别为：-0.02548231929540634 和 -0.025485152378678322,差异为2.8330832719802856e-06
# 在位置 (8, 408)，值分别为：-0.01296014804393053 和 -0.012948315590620041,差异为-1.1832453310489655e-05
# 在位置 (8, 409)，值分别为：0.009808038361370564 和 0.009696303866803646,差异为0.00011173449456691742
# 在位置 (8, 410)，值分别为：0.020040782168507576 和 0.019976641982793808,差异为6.4140185713768e-05
# 在位置 (8, 411)，值分别为：0.012780975550413132 和 0.012742576189339161,差异为3.8399361073970795e-05
# 在位置 (8, 412)，值分别为：0.019032107666134834 和 0.019007675349712372,差异为2.4432316422462463e-05
# 在位置 (8, 413)，值分别为：0.03248995915055275 和 0.0325201153755188,差异为-3.0156224966049194e-05
# 在位置 (8, 414)，值分别为：0.0031869488302618265 和 0.0031673929188400507,差异为1.9555911421775818e-05
# 在位置 (8, 415)，值分别为：-0.023199528455734253 和 -0.023202108219265938,差异为2.5797635316848755e-06
# 在位置 (8, 416)，值分别为：0.003961704205721617 和 0.003879185300320387,差异为8.251890540122986e-05
# 在位置 (8, 417)，值分别为：0.00866664294153452 和 0.008694153279066086,差异为-2.751033753156662e-05
# 在位置 (8, 418)，值分别为：-0.025296511128544807 和 -0.025312596932053566,差异为1.6085803508758545e-05
# 在位置 (8, 419)，值分别为：0.0015237962361425161 和 0.0016467457171529531,差异为-0.000122949481010437
# 在位置 (8, 420)，值分别为：-0.022509383037686348 和 -0.022485338151454926,差异为-2.4044886231422424e-05
# 在位置 (8, 421)，值分别为：-0.015647737309336662 和 -0.015662750229239464,差异为1.5012919902801514e-05
# 在位置 (8, 422)，值分别为：-0.011447135359048843 和 -0.011388677172362804,差异为-5.845818668603897e-05
# 在位置 (8, 423)，值分别为：0.01789071224629879 和 0.01783960685133934,差异为5.110539495944977e-05
# 在位置 (8, 424)，值分别为：-0.016590051352977753 和 -0.016538802534341812,差异为-5.124881863594055e-05
# 在位置 (8, 425)，值分别为：0.004678394645452499 和 0.004732008557766676,差异为-5.361391231417656e-05
# 在位置 (8, 426)，值分别为：-0.014293988235294819 和 -0.014282303862273693,差异为-1.1684373021125793e-05
# 在位置 (8, 427)，值分别为：0.013179137371480465 和 0.013240332715213299,差异为-6.119534373283386e-05
# 在位置 (8, 428)，值分别为：0.003420868655666709 和 0.0034013385884463787,差异为1.953006722033024e-05
# 在位置 (8, 429)，值分别为：0.015647737309336662 和 0.015649477019906044,差异为-1.7397105693817139e-06
# 在位置 (8, 430)，值分别为：0.0007710226345807314 和 0.0007897742325440049,差异为-1.8751597963273525e-05
# 在位置 (8, 431)，值分别为：-0.001157985650934279 和 -0.0011307377135381103,差异为-2.724793739616871e-05
# 在位置 (8, 432)，值分别为：0.014811597764492035 和 0.014799971133470535,差异为1.1626631021499634e-05
# 在位置 (8, 433)，值分别为：0.03432149812579155 和 0.034325312823057175,差异为-3.814697265625e-06
# 在位置 (8, 434)，值分别为：0.02687588334083557 和 0.026971785351634026,差异为-9.590201079845428e-05
# 在位置 (8, 435)，值分别为：0.007166902534663677 和 0.007174335885792971,差异为-7.433351129293442e-06
# 在位置 (8, 436)，值分别为：0.009529326111078262 和 0.009563568979501724,差异为-3.4242868423461914e-05
# 在位置 (8, 437)，值分别为：0.03254304453730583 和 0.0325201153755188,差异为2.292916178703308e-05
# 在位置 (8, 438)，值分别为：-0.003064182586967945 和 -0.0030761375091969967,差异为1.195492222905159e-05
# 在位置 (8, 439)，值分别为：-0.011460407637059689 和 -0.011408587917685509,差异为-5.181971937417984e-05
# 在位置 (8, 440)，值分别为：-0.021779419854283333 和 -0.021768568083643913,差异为-1.0851770639419556e-05
# 在位置 (8, 441)，值分别为：0.0368431881070137 和 0.03684728220105171,差异为-4.0940940380096436e-06
# 在位置 (8, 442)，值分别为：0.02869415283203125 和 0.028617702424526215,差异为7.64504075050354e-05
# 在位置 (8, 443)，值分别为：-0.005312134511768818 和 -0.005246357526630163,差异为-6.577698513865471e-05
# 在位置 (8, 444)，值分别为：0.0013869283720850945 和 0.0013016342418268323,差异为8.529413025826216e-05
# 在位置 (8, 445)，值分别为：-0.015899905934929848 和 -0.01584857888519764,差异为-5.132704973220825e-05
# 在位置 (8, 446)，值分别为：0.008381294086575508 和 0.008362315595149994,差异为1.897849142551422e-05
# 在位置 (8, 447)，值分别为：-0.01478505413979292 和 -0.014786697924137115,差异为1.6437843441963196e-06
# 在位置 (8, 448)，值分别为：0.003543635131791234 和 0.0036004413850605488,差异为-5.6806253269314766e-05
# 在位置 (8, 449)，值分别为：0.018209241330623627 和 0.01821126416325569,差异为-2.0228326320648193e-06
# 在位置 (8, 450)，值分别为：-0.009701861999928951 和 -0.009583478793501854,差异为-0.00011838320642709732
# 在位置 (8, 451)，值分别为：0.020876921713352203 和 0.020919062197208405,差异为-4.214048385620117e-05
# 在位置 (8, 452)，值分别为：0.021049458533525467 和 0.02109161764383316,差异为-4.215911030769348e-05
# 在位置 (8, 453)，值分别为：0.009031624533236027 和 0.009085722267627716,差异为-5.40977343916893e-05
# 在位置 (8, 454)，值分别为：0.02451346069574356 和 0.024529458954930305,差异为-1.599825918674469e-05
# 在位置 (8, 455)，值分别为：0.010776897892355919 和 0.010778095573186874,差异为-1.1976808309555054e-06
# 在位置 (8, 456)，值分别为：0.016271522268652916 和 0.016352972015738487,差异为-8.144974708557129e-05
# 在位置 (8, 457)，值分别为：0.02029295079410076 和 0.02032175473868847,差异为-2.880394458770752e-05
# 在位置 (8, 458)，值分别为：0.005779974162578583 和 0.005764024797827005,差异为1.5949364751577377e-05
# 在位置 (8, 459)，值分别为：0.009960667230188847 和 0.00992859061807394,差异为3.207661211490631e-05
# 在位置 (8, 460)，值分别为：0.002883350942283869 和 0.0028703981079161167,差异为1.2952834367752075e-05
# 在位置 (8, 461)，值分别为：-0.007876956835389137 和 -0.007944200187921524,差异为6.724335253238678e-05
# 在位置 (8, 462)，值分别为：0.002617910271510482 和 0.0026115644723176956,差异为6.345799192786217e-06
# 在位置 (8, 463)，值分别为：0.017213838174939156 和 0.017308665439486504,差异为-9.482726454734802e-05
# 在位置 (8, 464)，值分别为：0.022297030314803123 和 0.022219866514205933,差异为7.716380059719086e-05
# 在位置 (8, 465)，值分别为：-0.0023657414130866528 和 -0.002399188233539462,差异为3.3446820452809334e-05
# 在位置 (8, 466)，值分别为：-2.5883073249133304e-05 和 -4.426665782375494e-06,差异为-2.145640792150516e-05
# 在位置 (8, 467)，值分别为：-0.00870645884424448 和 -0.008700789883732796,差异为-5.668960511684418e-06
# 在位置 (8, 468)，值分别为：0.008965264074504375 和 0.008972897194325924,差异为-7.633119821548462e-06
# 在位置 (8, 469)，值分别为：-0.011135242879390717 和 -0.011109933257102966,差异为-2.5309622287750244e-05
# 在位置 (8, 470)，值分别为：0.013504302129149437 和 0.013479256071150303,差异为2.5046057999134064e-05
# 在位置 (8, 471)，值分别为：-0.0027489715721458197 和 -0.00272936699911952,差异为-1.9604573026299477e-05
# 在位置 (8, 472)，值分别为：-0.025973385199904442 和 -0.026029366999864578,差异为5.5981799960136414e-05
# 在位置 (8, 473)，值分别为：0.024394012987613678 和 0.024423271417617798,差异为-2.9258430004119873e-05
# 在位置 (8, 474)，值分别为：-0.0038688001222908497 和 -0.0038725484628230333,差异为3.748340532183647e-06
# 在位置 (8, 475)，值分别为：-0.016258250921964645 和 -0.016326425597071648,差异为6.817467510700226e-05
# 在位置 (8, 476)，值分别为：-0.019854974001646042 和 -0.019764266908168793,差异为-9.070709347724915e-05
# 在位置 (8, 477)，值分别为：-0.00141596095636487 和 -0.0013978672213852406,差异为-1.8093734979629517e-05
# 在位置 (8, 478)，值分别为：0.021553795784711838 和 0.02150309644639492,差异为5.069933831691742e-05
# 在位置 (8, 479)，值分别为：0.014400164596736431 和 0.01441503968089819,差异为-1.4875084161758423e-05
# 在位置 (8, 480)，值分别为：-0.0020123731810599566 和 -0.0020076194778084755,差异为-4.753703251481056e-06
# 在位置 (8, 481)，值分别为：0.00044088062713854015 和 0.0004106494307052344,差异为3.023119643330574e-05
# 在位置 (8, 482)，值分别为：-0.009403240866959095 和 -0.009377739392220974,差异为-2.5501474738121033e-05
# 在位置 (8, 483)，值分别为：-0.008646734990179539 和 -0.008654332719743252,差异为7.597729563713074e-06
# 在位置 (8, 484)，值分别为：0.04106369614601135 和 0.04106825962662697,差异为-4.563480615615845e-06
# 在位置 (8, 485)，值分别为：-0.01152013149112463 和 -0.01153468620032072,差异为1.4554709196090698e-05
# 在位置 (8, 486)，值分别为：0.012362906709313393 和 0.01235764380544424,差异为5.262903869152069e-06
# 在位置 (8, 487)，值分别为：0.015727369114756584 和 0.01575566455721855,差异为-2.8295442461967468e-05
# 在位置 (8, 488)，值分别为：-0.003965022508054972 和 -0.004005283582955599,差异为4.0261074900627136e-05
# 在位置 (8, 489)，值分别为：0.005620709620416164 和 0.005581513978540897,差异为3.919564187526703e-05
# 在位置 (8, 490)，值分别为：-0.009044895879924297 和 -0.009025990962982178,差异为-1.89049169421196e-05
# 在位置 (8, 491)，值分别为：0.011228146962821484 和 0.011249305680394173,差异为-2.1158717572689056e-05
# 在位置 (8, 492)，值分别为：-0.01150686014443636 和 -0.011435134336352348,差异为-7.172580808401108e-05
# 在位置 (8, 493)，值分别为：-0.0028684199787676334 和 -0.00283223669975996,差异为-3.6183279007673264e-05
# 在位置 (8, 494)，值分别为：-0.0011413955362513661 和 -0.0010436302982270718,差异为-9.776523802429438e-05
# 在位置 (8, 495)，值分别为：0.008036221377551556 和 0.008050387725234032,差异为-1.4166347682476044e-05
# 在位置 (8, 496)，值分别为：-0.0060985032469034195 和 -0.0060626789927482605,差异为-3.5824254155158997e-05
# 在位置 (8, 497)，值分别为：-0.024579821154475212 和 -0.024569280445575714,差异为-1.0540708899497986e-05
# 在位置 (8, 498)，值分别为：0.0070806341245770454 和 0.007094694767147303,差异为-1.4060642570257187e-05
# 在位置 (8, 499)，值分别为：0.005275636445730925 和 0.005289496388286352,差异为-1.3859942555427551e-05
# 在位置 (8, 500)，值分别为：0.018594130873680115 和 0.018543103709816933,差异为5.102716386318207e-05
# 在位置 (8, 501)，值分别为：-0.019098468124866486 和 -0.01912713795900345,差异为2.866983413696289e-05
# 在位置 (8, 502)，值分别为：0.0015536583960056305 和 0.0015762301627546549,差异为-2.257176674902439e-05
# 在位置 (8, 503)，值分别为：0.003775895806029439 和 0.003739813342690468,差异为3.608246333897114e-05
# 在位置 (8, 504)，值分别为：0.0021583656780421734 和 0.0021221034694463015,差异为3.6262208595871925e-05
# 在位置 (8, 505)，值分别为：0.007890228182077408 和 0.00793092604726553,差异为-4.0697865188121796e-05
# 在位置 (8, 506)，值分别为：-0.010995886288583279 和 -0.010970561765134335,差异为-2.5324523448944092e-05
# 在位置 (8, 507)，值分别为：-0.006101821083575487 和 -0.0060659972950816154,差异为-3.582378849387169e-05
# 在位置 (8, 508)，值分别为：0.0031305428128689528 和 0.0030396352522075176,差异为9.090756066143513e-05
# 在位置 (8, 509)，值分别为：0.006158227100968361 和 0.006059360224753618,差异为9.886687621474266e-05
# 在位置 (8, 510)，值分别为：-0.024752357974648476 和 -0.02470201440155506,差异为-5.034357309341431e-05
# 在位置 (8, 511)，值分别为：-0.013948915526270866 和 -0.013977013528347015,差异为2.8098002076148987e-05
# 在位置 (8, 512)，值分别为：-0.016218435019254684 和 -0.01624678447842598,差异为2.8349459171295166e-05
# 在位置 (8, 513)，值分别为：0.020916737616062164 和 0.020945608615875244,差异为-2.8870999813079834e-05
# 在位置 (8, 514)，值分别为：0.04945162683725357 和 0.04940402880311012,差异为4.7598034143447876e-05
# 在位置 (8, 515)，值分别为：-0.017160749062895775 和 -0.01708301529288292,差异为-7.773377001285553e-05
# 在位置 (8, 516)，值分别为：0.002196522895246744 和 0.002163583179935813,差异为3.2939715310931206e-05
# 在位置 (8, 517)，值分别为：-0.03336591273546219 和 -0.03334307298064232,差异为-2.2839754819869995e-05
# 在位置 (8, 518)，值分别为：-0.01885957084596157 和 -0.018848393112421036,差异为-1.1177733540534973e-05
# 在位置 (8, 519)，值分别为：0.04931890591979027 和 0.04937748238444328,差异为-5.857646465301514e-05
# 在位置 (8, 520)，值分别为：0.0202531348913908 和 0.02028193324804306,差异为-2.8798356652259827e-05
# 在位置 (8, 521)，值分别为：0.014333805069327354 和 0.014282303862273693,差异为5.1501207053661346e-05
# 在位置 (8, 522)，值分别为：0.0067123351618647575 和 0.006742946337908506,差异为-3.0611176043748856e-05
# 在位置 (8, 523)，值分别为：0.007372619118541479 和 0.0073468913324177265,差异为2.5727786123752594e-05
# 在位置 (8, 524)，值分别为：-0.005750111769884825 和 -0.005740796215832233,差异为-9.315554052591324e-06
# 在位置 (8, 525)，值分别为：0.0010567862773314118 和 0.0011033611372113228,差异为-4.6574859879910946e-05
# 在位置 (8, 526)，值分别为：-0.020492032170295715 和 -0.020481036975979805,差异为-1.099519431591034e-05
# 在位置 (8, 527)，值分别为：-0.006626066751778126 和 -0.0065703908912837505,差异为-5.567586049437523e-05
# 在位置 (8, 528)，值分别为：0.018700307235121727 和 0.01872893236577511,差异为-2.8625130653381348e-05
# 在位置 (8, 529)，值分别为：0.01597953774034977 和 0.015981314703822136,差异为-1.776963472366333e-06
# 在位置 (8, 530)，值分别为：-0.018912658095359802 和 -0.018994402140378952,差异为8.174404501914978e-05
# 在位置 (8, 531)，值分别为：-0.007326167076826096 和 -0.00731370784342289,差异为-1.2459233403205872e-05
# 在位置 (8, 532)，值分别为：0.002088687615469098 和 0.0020590543281286955,差异为2.9633287340402603e-05
# 在位置 (8, 533)，值分别为：0.03004790097475052 和 0.03007778897881508,差异为-2.9888004064559937e-05
# 在位置 (8, 534)，值分别为：-0.0015661008656024933 和 -0.0014899522066116333,差异为-7.614865899085999e-05
# 在位置 (8, 535)，值分别为：-0.010358828119933605 和 -0.010386526584625244,差异为2.7698464691638947e-05
# 在位置 (8, 536)，值分别为：-0.01150022353976965 和 -0.011488229036331177,差异为-1.1994503438472748e-05
# 在位置 (8, 537)，值分别为：0.017983615398406982 和 0.01789270155131817,差异为9.091384708881378e-05
# 在位置 (8, 538)，值分别为：0.004120968747884035 和 0.004055059514939785,差异为6.590923294425011e-05
# 在位置 (8, 539)，值分别为：-0.03142819553613663 和 -0.03137859329581261,差异为-4.9602240324020386e-05
# 在位置 (8, 540)，值分别为：0.0017568864859640598 和 0.0017653777031227946,差异为-8.491217158734798e-06
# 在位置 (8, 541)，值分别为：0.013882555067539215 和 0.013884098269045353,差异为-1.543201506137848e-06
# ...
# 在位置 (8, 1359)，值分别为：-0.027181141078472137 和 -0.02714434266090393,差异为-3.679841756820679e-05
# 在位置 (8, 1360)，值分别为：-0.0007100542425177991 和 -0.0006852453225292265,差异为-2.4808919988572598e-05
# 在位置 (8, 1361)，值分别为：-0.024632908403873444 和 -0.024569280445575714,差异为-6.362795829772949e-05
# 在位置 (8, 1362)，值分别为：0.0005541077116504312 和 0.0005819607758894563,差异为-2.7853064239025116e-05
# 在位置 (8, 1363)，值分别为：-0.019178099930286407 和 -0.019233325496315956,差异为5.5225566029548645e-05
# 在位置 (8, 1364)，值分别为：-0.02451346069574356 和 -0.024595826864242554,差异为8.236616849899292e-05
# 在位置 (8, 1365)，值分别为：0.017704904079437256 和 0.017706871032714844,差异为-1.9669532775878906e-06
# 在位置 (8, 1366)，值分别为：0.0017933845520019531 和 0.0019030905095860362,差异为-0.00010970595758408308
# 在位置 (8, 1367)，值分别为：0.014904502779245377 和 0.01483979169279337,差异为6.47110864520073e-05
# 在位置 (8, 1368)，值分别为：0.02111581712961197 和 0.02113143913447857,差异为-1.5622004866600037e-05
# 在位置 (8, 1369)，值分别为：-0.01889938674867153 和 -0.018914761021733284,差异为1.537427306175232e-05
# 在位置 (8, 1370)，值分别为：-0.022681917995214462 和 -0.02276408113539219,差异为8.216314017772675e-05
# 在位置 (8, 1371)，值分别为：0.009097984060645103 和 0.009032628498971462,差异为6.53555616736412e-05
# 在位置 (8, 1372)，值分别为：-0.009529326111078262 和 -0.009503837674856186,差异为-2.5488436222076416e-05
# 在位置 (8, 1373)，值分别为：-0.006135001312941313 和 -0.006132364738732576,差异为-2.6365742087364197e-06
# 在位置 (8, 1374)，值分别为：0.020359311252832413 和 0.020388122648000717,差异为-2.8811395168304443e-05
# 在位置 (8, 1375)，值分别为：-0.0006474267574958503 和 -0.0006582834757864475,差异为1.08567182905972e-05
# 在位置 (8, 1376)，值分别为：0.024632908403873444 和 0.024622373282909393,差异为1.0535120964050293e-05
# 在位置 (8, 1377)，值分别为：-0.0042802332900464535 和 -0.004277390893548727,差异为-2.8423964977264404e-06
# 在位置 (8, 1378)，值分别为：0.008155669085681438 和 0.008163212798535824,差异为-7.543712854385376e-06
# 在位置 (8, 1379)，值分别为：0.030207166448235512 和 0.030183976516127586,差异为2.3189932107925415e-05
# 在位置 (8, 1380)，值分别为：-0.011234782636165619 和 -0.011236031539738178,差异为1.2489035725593567e-06
# 在位置 (8, 1381)，值分别为：-0.005965782795101404 和 -0.005926625337451696,差异为-3.9157457649707794e-05
# 在位置 (8, 1382)，值分别为：0.0038588461466133595 和 0.0038327279035001993,差异为2.6118243113160133e-05
# 在位置 (8, 1383)，值分别为：0.008042857050895691 和 0.008057024329900742,差异为-1.416727900505066e-05
# 在位置 (8, 1384)，值分别为：-0.032622676342725754 和 -0.032679397612810135,差异为5.6721270084381104e-05
# 在位置 (8, 1385)，值分别为：0.022761551663279533 和 0.022817175835371017,差异为-5.562417209148407e-05
# 在位置 (8, 1386)，值分别为：0.017094388604164124 和 0.017109563574194908,差异为-1.5174970030784607e-05
# 在位置 (8, 1387)，值分别为：0.01742619089782238 和 0.01745467446744442,差异为-2.8483569622039795e-05
# 在位置 (8, 1388)，值分别为：-0.004187329206615686 和 -0.004121426958590746,差异为-6.590224802494049e-05
# 在位置 (8, 1389)，值分别为：-0.017585454508662224 和 -0.017640503123402596,差异为5.5048614740371704e-05
# 在位置 (8, 1390)，值分别为：-0.02675643563270569 和 -0.02678595669567585,差异为2.9521062970161438e-05
# 在位置 (8, 1391)，值分别为：0.0032732172403484583 和 0.003323356853798032,差异为-5.013961344957352e-05
# 在位置 (8, 1392)，值分别为：-0.004067880567163229 和 -0.004098198376595974,差异为3.031780943274498e-05
# 在位置 (8, 1393)，值分别为：-0.0263715460896492 和 -0.02636120468378067,差异为-1.0341405868530273e-05
# 在位置 (8, 1394)，值分别为：0.0022595650516450405 和 0.0022647937294095755,差异为-5.22867776453495e-06
# 在位置 (8, 1395)，值分别为：-0.030870769172906876 和 -0.03087420016527176,差异为3.430992364883423e-06
# 在位置 (8, 1396)，值分别为：-0.00495378952473402 和 -0.004911201074719429,差异为-4.258845001459122e-05
# 在位置 (8, 1397)，值分别为：0.028481800109148026 和 0.028484966605901718,差异为-3.166496753692627e-06
# 在位置 (8, 1398)，值分别为：-0.010717173106968403 和 -0.010758185759186745,差异为4.101265221834183e-05
# 在位置 (8, 1399)，值分别为：0.01010665949434042 和 0.01013433001935482,差异为-2.7670525014400482e-05
# 在位置 (8, 1400)，值分别为：0.015594648197293282 和 0.015569834969937801,差异为2.4813227355480194e-05
# 在位置 (8, 1401)，值分别为：-0.01921791583299637 和 -0.019246598705649376,差异为2.8682872653007507e-05
# 在位置 (8, 1402)，值分别为：-0.020054055377840996 和 -0.020003190264105797,差异为-5.0865113735198975e-05
# 在位置 (8, 1403)，值分别为：-0.012143918313086033 和 -0.012178451754152775,差异为3.453344106674194e-05
# 在位置 (8, 1404)，值分别为：-0.02546904794871807 和 -0.025432057678699493,差异为-3.6990270018577576e-05
# 在位置 (8, 1405)，值分别为：2.4742506866459735e-05 和 -6.137705440778518e-06,差异为3.08802118524909e-05
# 在位置 (8, 1406)，值分别为：-0.011599764227867126 和 -0.011620963923633099,差异为2.1199695765972137e-05
# 在位置 (8, 1407)，值分别为：0.013457849621772766 和 0.013472619466483593,差异为-1.4769844710826874e-05
# 在位置 (8, 1408)，值分别为：-0.003629903309047222 和 -0.00355730252340436,差异为-7.260078564286232e-05
# 在位置 (8, 1409)，值分别为：0.019589532166719437 和 0.019618257880210876,差异为-2.872571349143982e-05
# 在位置 (8, 1410)，值分别为：0.02358441799879074 和 0.02356049232184887,差异为2.3925676941871643e-05
# 在位置 (8, 1411)，值分别为：0.018660489469766617 和 0.018596196547150612,差异为6.429292261600494e-05
# 在位置 (8, 1412)，值分别为：-0.014917774125933647 和 -0.014866339042782784,差异为-5.143508315086365e-05
# 在位置 (8, 1413)，值分别为：-0.010113295167684555 和 -0.010061325505375862,差异为-5.196966230869293e-05
# 在位置 (8, 1414)，值分别为：-0.007014273665845394 和 -0.007028327323496342,差异为1.405365765094757e-05
# 在位置 (8, 1415)，值分别为：-0.006184771191328764 和 -0.006132364738732576,差异为-5.240645259618759e-05
# 在位置 (8, 1416)，值分别为：0.017611999064683914 和 0.017653778195381165,差异为-4.1779130697250366e-05
# 在位置 (8, 1417)，值分别为：-0.008865723386406898 和 -0.0089397132396698,差异为7.39898532629013e-05
# 在位置 (8, 1418)，值分别为：-0.023438425734639168 和 -0.023387936875224113,差异为-5.048885941505432e-05
# 在位置 (8, 1419)，值分别为：-6.231637962628156e-05 和 -6.097521691117436e-05,差异为-1.3411627151072025e-06
# 在位置 (8, 1420)，值分别为：0.012986692599952221 和 0.013021320104598999,差异为-3.462750464677811e-05
# 在位置 (8, 1421)，值分别为：0.003968340344727039 和 0.003988691605627537,差异为-2.0351260900497437e-05
# 在位置 (8, 1422)，值分别为：0.011958109214901924 和 0.01193289179354906,差异为2.5217421352863312e-05
# 在位置 (8, 1423)，值分别为：0.009920851327478886 和 0.009955137968063354,差异为-3.428664058446884e-05
# 在位置 (8, 1424)，值分别为：0.014758509583771229 和 0.014799971133470535,差异为-4.146154969930649e-05
# 在位置 (8, 1425)，值分别为：-0.012369542382657528 和 -0.012437284924089909,差异为6.774254143238068e-05
# 在位置 (8, 1426)，值分别为：-0.008374658413231373 和 -0.00830922182649374,差异为-6.543658673763275e-05
# 在位置 (8, 1427)，值分别为：-0.016629867255687714 和 -0.01665826328098774,差异为2.839602530002594e-05
# 在位置 (8, 1428)，值分别为：0.01738637499511242 和 0.017335213720798492,差异为5.11612743139267e-05
# 在位置 (8, 1429)，值分别为：0.010869801975786686 和 0.010791368782520294,差异为7.843319326639175e-05
# 在位置 (8, 1430)，值分别为：-0.014692150056362152 和 -0.014680509455502033,差异为-1.1640600860118866e-05
# 在位置 (8, 1431)，值分别为：-0.02358441799879074 和 -0.023613587021827698,差异为2.9169023036956787e-05
# 在位置 (8, 1432)，值分别为：0.023717137053608894 和 0.023733047768473625,差异为-1.5910714864730835e-05
# 在位置 (8, 1433)，值分别为：0.0071469941176474094 和 0.00710796844214201,差异为3.9025675505399704e-05
# 在位置 (8, 1434)，值分别为：0.030233711004257202 和 0.030290165916085243,差异为-5.645491182804108e-05
# 在位置 (8, 1435)，值分别为：-0.004346593748778105 和 -0.004386897198855877,差异为4.030345007777214e-05
# 在位置 (8, 1436)，值分别为：0.025681400671601295 和 0.02560461312532425,差异为7.67875462770462e-05
# 在位置 (8, 1437)，值分别为：0.005113054066896439 和 0.005090393591672182,差异为2.2660475224256516e-05
# 在位置 (8, 1438)，值分别为：-0.011115334928035736 和 -0.01112320739775896,差异为7.87246972322464e-06
# 在位置 (8, 1439)，值分别为：-0.034109145402908325 和 -0.03405984491109848,差异为-4.930049180984497e-05
# 在位置 (8, 1440)，值分别为：0.009011715650558472 和 0.009092358872294426,差异为-8.064322173595428e-05
# 在位置 (8, 1441)，值分别为：-0.022363388910889626 和 -0.02225968800485134,差异为-0.0001037009060382843
# 在位置 (8, 1442)，值分别为：-0.011493587866425514 和 -0.011501502245664597,差异为7.914379239082336e-06
# 在位置 (8, 1443)，值分别为：0.019868245348334312 和 0.01984390802681446,差异为2.4337321519851685e-05
# 在位置 (8, 1444)，值分别为：0.030870769172906876 和 0.03087420016527176,差异为-3.430992364883423e-06
# 在位置 (8, 1445)，值分别为：-0.004555628169327974 和 -0.004519632551819086,差异为-3.5995617508888245e-05
# 在位置 (8, 1446)，值分别为：-0.019496629014611244 和 -0.0194987952709198,差异为2.166256308555603e-06
# 在位置 (8, 1447)，值分别为：-0.008825907483696938 和 -0.008820251561701298,差异为-5.655921995639801e-06
# 在位置 (8, 1448)，值分别为：0.0178641676902771 和 0.01785288006067276,差异为1.12876296043396e-05
# 在位置 (8, 1449)，值分别为：0.01793052814900875 和 0.017932521179318428,差异为-1.993030309677124e-06
# 在位置 (8, 1450)，值分别为：-0.017996888607740402 和 -0.018012162297964096,差异为1.5273690223693848e-05
# 在位置 (8, 1451)，值分别为：-0.019655892625451088 和 -0.019671352580189705,差异为1.5459954738616943e-05
# 在位置 (8, 1452)，值分别为：-0.006861645262688398 和 -0.006888955365866423,差异为2.7310103178024292e-05
# 在位置 (8, 1453)，值分别为：-0.0055078971199691296 和 -0.005462052300572395,差异为-4.584481939673424e-05
# 在位置 (8, 1454)，值分别为：-0.007087270263582468 和 -0.0071212416514754295,差异为3.39713878929615e-05
# 在位置 (8, 1455)，值分别为：-0.023345520719885826 和 -0.023334842175245285,差异为-1.0678544640541077e-05
# 在位置 (8, 1456)，值分别为：-0.0197620689868927 和 -0.019750993698835373,差异为-1.107528805732727e-05
# 在位置 (8, 1457)，值分别为：0.017784535884857178 和 0.017786512151360512,差异为-1.9762665033340454e-06
# 在位置 (8, 1458)，值分别为：-0.013278677128255367 和 -0.013240332715213299,差异为-3.834441304206848e-05
# 在位置 (8, 1459)，值分别为：0.01341139804571867 和 0.013346521183848381,差异为6.487686187028885e-05
# 在位置 (8, 1460)，值分别为：0.029039226472377777 和 0.028989359736442566,差异为4.986673593521118e-05
# 在位置 (8, 1461)，值分别为：-0.013816195540130138 和 -0.013791183941066265,差异为-2.501159906387329e-05
# 在位置 (8, 1462)，值分别为：0.027632391080260277 和 0.02763546258211136,差异为-3.071501851081848e-06
# 在位置 (8, 1463)，值分别为：-0.0012475718976929784 和 -0.001256836112588644,差异为9.264214895665646e-06
# 在位置 (8, 1464)，值分别为：-0.01502395048737526 和 -0.01503889448940754,差异为1.4944002032279968e-05
# 在位置 (8, 1465)，值分别为：0.023823313415050507 和 0.023852510377764702,差异为-2.919696271419525e-05
# 在位置 (8, 1466)，值分别为：-0.021859051659703255 和 -0.02190130203962326,差异为4.22503799200058e-05
# 在位置 (8, 1467)，值分别为：-0.0375598780810833 和 -0.03759060055017471,差异为3.0722469091415405e-05
# 在位置 (8, 1468)，值分别为：0.022456293925642967 和 0.022445516660809517,差异为1.0777264833450317e-05
# 在位置 (8, 1469)，值分别为：0.01686876453459263 和 0.016777725890278816,差异为9.103864431381226e-05
# 在位置 (8, 1470)，值分别为：0.02500452660024166 和 0.024994032457470894,差异为1.0494142770767212e-05
# 在位置 (8, 1471)，值分别为：0.00029343654750846326 和 0.0003077796718571335,差异为-1.4343124348670244e-05
# 在位置 (8, 1472)，值分别为：-0.024155115708708763 和 -0.024131253361701965,差异为-2.386234700679779e-05
# 在位置 (8, 1473)，值分别为：0.03347208723425865 和 0.033475808799266815,差异为-3.721565008163452e-06
# 在位置 (8, 1474)，值分别为：0.005889468360692263 和 0.005959808826446533,差异为-7.034046575427055e-05
# 在位置 (8, 1475)，值分别为：0.0188462994992733 和 0.018821846693754196,差异为2.4452805519104004e-05
# 在位置 (8, 1476)，值分别为：-0.021872324869036674 和 -0.02194112353026867,差异为6.879866123199463e-05
# 在位置 (8, 1477)，值分别为：0.030684959143400192 和 0.030661823228001595,差异为2.3135915398597717e-05
# 在位置 (8, 1478)，值分别为：-0.015342479571700096 和 -0.015384006313979626,差异为4.152674227952957e-05
# 在位置 (8, 1479)，值分别为：0.00799640454351902 和 0.008010567165911198,差异为-1.4162622392177582e-05
# 在位置 (8, 1480)，值分别为：0.03490546718239784 和 0.034882802516222,差异为2.2664666175842285e-05
# 在位置 (8, 1481)，值分别为：-0.007618151605129242 和 -0.007572541479021311,差异为-4.561012610793114e-05
# 在位置 (8, 1482)，值分别为：-0.008560466580092907 和 -0.008587965741753578,差异为2.7499161660671234e-05
# 在位置 (8, 1483)，值分别为：-0.00613831914961338 和 -0.006089225877076387,差异为-4.909327253699303e-05
# 在位置 (8, 1484)，值分别为：0.004260325338691473 和 0.004284027498215437,差异为-2.3702159523963928e-05
# 在位置 (8, 1485)，值分别为：0.0036133131943643093 和 0.003613715060055256,差异为-4.01865690946579e-07
# 在位置 (8, 1486)，值分别为：0.022469565272331238 和 0.022445516660809517,差异为2.4048611521720886e-05
# 在位置 (8, 1487)，值分别为：0.022761551663279533 和 0.022830449044704437,差异为-6.889738142490387e-05
# 在位置 (8, 1488)，值分别为：0.06959858536720276 和 0.06965941935777664,差异为-6.083399057388306e-05
# 在位置 (8, 1489)，值分别为：0.012143918313086033 和 0.012171815149486065,差异为-2.7896836400032043e-05
# 在位置 (8, 1490)，值分别为：0.0026892474852502346 和 0.002709456719458103,差异为-2.0209234207868576e-05
# 在位置 (8, 1491)，值分别为：0.013464486226439476 和 0.013432798907160759,差异为3.168731927871704e-05
# 在位置 (8, 1492)，值分别为：-0.006410396192222834 和 -0.0064277006313204765,差异为1.73044390976429e-05
# 在位置 (8, 1493)，值分别为：0.01175239309668541 和 0.011793519370257854,差异为-4.1126273572444916e-05
# 在位置 (8, 1494)，值分别为：-0.0039550685323774815 和 -0.004008601885288954,差异为5.353335291147232e-05
# 在位置 (8, 1495)，值分别为：-0.0054415371268987656 和 -0.005448778625577688,差异为7.241498678922653e-06
# 在位置 (8, 1496)，值分别为：-0.011699304915964603 和 -0.011720514856278896,差异为2.1209940314292908e-05
# 在位置 (8, 1497)，值分别为：-0.02252265438437462 和 -0.022604798898100853,差异为8.214451372623444e-05
# 在位置 (8, 1498)，值分别为：0.015369024127721786 和 0.015330911614000797,差异为3.811251372098923e-05
# 在位置 (8, 1499)，值分别为：-0.005697023589164019 和 -0.005737477447837591,差异为4.045385867357254e-05
# 在位置 (8, 1500)，值分别为：0.004366501700133085 和 0.004333803430199623,差异为3.269826993346214e-05
# 在位置 (8, 1501)，值分别为：-0.013192408718168736 和 -0.013200512155890465,差异为8.103437721729279e-06
# 在位置 (8, 1502)，值分别为：-0.009184252470731735 和 -0.009158726781606674,差异为-2.5525689125061035e-05
# 在位置 (8, 1503)，值分别为：-0.0277120228856802 和 -0.027741650119423866,差异为2.9627233743667603e-05
# 在位置 (8, 1504)，值分别为：-0.0019211280159652233 和 -0.001937933498993516,差异为1.6805483028292656e-05
# 在位置 (8, 1505)，值分别为：0.011885113082826138 和 0.011839976534247398,差异为4.5136548578739166e-05
# 在位置 (8, 1506)，值分别为：-0.040692079812288284 和 -0.04067005589604378,差异为-2.2023916244506836e-05
# 在位置 (8, 1507)，值分别为：0.008885631337761879 和 0.008879982866346836,差异为5.648471415042877e-06
# 在位置 (8, 1508)，值分别为：0.017585454508662224 和 0.017613956704735756,差异为-2.8502196073532104e-05
# 在位置 (8, 1509)，值分别为：0.004774617031216621 和 0.004761874210089445,差异为1.2742821127176285e-05
# 在位置 (8, 1510)，值分别为：0.03113620914518833 和 0.031086577102541924,差异为4.963204264640808e-05
# 在位置 (8, 1511)，值分别为：0.010650813579559326 和 0.010658633895218372,差异为-7.820315659046173e-06
# 在位置 (8, 1512)，值分别为：0.0036829914897680283 和 0.0036701273638755083,差异为1.2864125892519951e-05
# 在位置 (8, 1513)，值分别为：-0.011440499685704708 和 -0.011428497731685638,差异为-1.2001954019069672e-05
# 在位置 (8, 1514)，值分别为：0.02361096255481243 和 0.023693228140473366,差异为-8.226558566093445e-05
# 在位置 (8, 1515)，值分别为：-0.003560225013643503 和 -0.0035241188015788794,差异为-3.610621206462383e-05
# 在位置 (8, 1516)，值分别为：-0.018142880871891975 和 -0.018171444535255432,差异为2.8563663363456726e-05
# 在位置 (8, 1517)，值分别为：-0.03105657733976841 和 -0.031060028821229935,差异为3.4514814615249634e-06
# 在位置 (8, 1518)，值分别为：-0.014997406862676144 和 -0.01503889448940754,差异为4.148762673139572e-05
# 在位置 (8, 1519)，值分别为：-0.0018547677900642157 和 -0.00188152096234262,差异为2.6753172278404236e-05
# 在位置 (8, 1520)，值分别为：-0.022934086620807648 和 -0.022976458072662354,差异为4.237145185470581e-05
# 在位置 (8, 1521)，值分别为：-0.019098468124866486 和 -0.01907404325902462,差异为-2.442486584186554e-05
# 在位置 (8, 1522)，值分别为：0.014692150056362152 和 0.014653962105512619,差异为3.818795084953308e-05
# 在位置 (8, 1523)，值分别为：0.0008058617822825909 和 0.0008018033695407212,差异为4.058412741869688e-06
# 在位置 (8, 1524)，值分别为：-0.008938719518482685 和 -0.008952987380325794,差异为1.4267861843109131e-05
# 在位置 (8, 1525)，值分别为：-0.002730722539126873 和 -0.002812326420098543,差异为8.160388097167015e-05
# 在位置 (8, 1526)，值分别为：0.0007660456467419863 和 0.0007777450955472887,差异为-1.1699448805302382e-05
# 在位置 (8, 1527)，值分别为：0.005066602025181055 和 0.005033981055021286,差异为3.262097015976906e-05
# 在位置 (8, 1528)，值分别为：0.0002739432384259999 和 0.0003287269501015544,差异为-5.4783711675554514e-05
# 在位置 (8, 1529)，值分别为：0.046797219663858414 和 0.04674932733178139,差异为4.789233207702637e-05
# 在位置 (8, 1530)，值分别为：-0.0046352604404091835 和 -0.004632457159459591,差异为-2.8032809495925903e-06
# 在位置 (8, 1531)，值分别为：-0.026544082909822464 和 -0.026573579758405685,差异为2.9496848583221436e-05
# 在位置 (8, 1532)，值分别为：-0.006801921408623457 和 -0.0067329914309084415,差异为-6.892997771501541e-05
# 在位置 (8, 1533)，值分别为：-0.009993847459554672 和 -0.010034779086709023,差异为4.093162715435028e-05
# 在位置 (8, 1534)，值分别为：-0.009940759278833866 和 -0.00991531740874052,差异为-2.5441870093345642e-05
# 在位置 (8, 1535)，值分别为：-0.0018298827344551682 和 -0.0018715658225119114,差异为4.1683088056743145e-05
# 在位置 (8, 1536)，值分别为：-0.013776378706097603 和 -0.013764636591076851,差异为-1.1742115020751953e-05

# %%
np.load('result/text_problem_embeddings.npy')

# %%
c13k_problems = pd.read_json("data/c13k_problems_test.json", orient='index')
behavioral_embeddings = behavioral_embedding_model(c13k_problems)
c13k_problems_prepro = preprocess_data(c13k_problems)
# pool = multiprocessing.Pool(processes=4)
# text_problem_embeddings = pool.starmap(text_embedding_multiple, c13k_problems_prepro)
text_problem_embeddings_direct = text_embedding_direct(c13k_problems_prepro,query = 'online')

# %%
np.save('result/text_problem_embeddings_direct.npy', text_problem_embeddings_direct)
np.load('result/text_problem_embeddings_direct.npy')

# %%
batch_size= 256
train_dataloader, val_dataloader,test_dataloader = create_data_loaders(text_problem_embeddings, behavioral_embeddings, batch_size=batch_size, test_size = 0.2, contrastive = False, false_scale = 2, scale = 'outcome_scaling')

# %%
# Define the model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# model = JointEmbedding().to(device)
model = TextDecisionModel().to(device)

# %%
# Define the loss, optimizer, etc.
criterion = FeatureLoss()
# criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

# %%
num_epochs = 200
# cosine_similarity_threshold = 0.9 # This can be adjusted based on your needs

# %%
feature_losses = {f"dim_{i}": [] for i in range(12)}
val_feature_losses = {f"dim_{i}": [] for i in range(12)}
for epoch in range(num_epochs):
    model.train()
    total_loss = 0
    # true_pairs_similarity = []
    # false_pairs_similarity = []
    # For storing dimensional losses in an epoch
    epoch_dimensional_losses = {f"dim_{i}": [] for i in range(12)}
    val_epoch_dimensional_losses = {f"dim_{i}": [] for i in range(12)}
    
    for batch in train_dataloader:
        text_embeds = batch["text_embedding"].to(device)
        decision_embeds = batch["decision_embedding"].to(device)
        # labels = batch["label"].to(device)

        optimizer.zero_grad()
        # text_outputs, behavioral_outputs = model(text_embeds, decision_embeds)
        
        decision_pred = model(text_embeds)
        #dimensional-wise loss to track the training
        feature_loss = criterion(decision_pred, decision_embeds)
        #MSE loss indeed
        loss = torch.mean(torch.sum(feature_loss, dim=1))
        # loss = criterion(text_outputs, behavioral_outputs,labels)
        loss.backward()
        optimizer.step()
        
        for i in range(12):
            epoch_dimensional_losses[f"dim_{i}"].append(feature_loss[:, i].mean().item())
        
        total_loss += loss.item()
    
    # Store the average dimensional loss for this epoch
    for i in range(12):
        feature_losses[f"dim_{i}"].append(np.mean(epoch_dimensional_losses[f"dim_{i}"]))
        
    print(f"Epoch {epoch + 1}/{num_epochs} - Loss: {total_loss/len(train_dataloader)}")

    model.eval()
    with torch.no_grad():
        # correct_pairs = 0
        # total_pairs = 0
        total_val_loss = 0
        # true_pairs_val_similarity = []
        # false_pairs_val_similarity = []

        for batch in test_dataloader:
            text_emb = batch["text_embedding"].to(device)
            decision_emb = batch["decision_embedding"].to(device)
            # label = batch["label"].to(device)
    
            # text_proj, decision_proj = model(text_emb, decision_emb)
            # cosine_sim = nn.functional.cosine_similarity(text_proj, decision_proj)
            # loss = criterion(text_proj, decision_proj, label)
            decision_pred = model(text_embeds)
            val_feature_loss = criterion(decision_pred, decision_embeds)
            loss = torch.mean(torch.sum(val_feature_loss, dim=1))
            total_val_loss += loss.item()

            # # Calculate similarity for validation
            # true_pairs_val_similarity.extend(cosine_sim[label == 1].cpu().numpy())
            # false_pairs_val_similarity.extend(cosine_sim[label == 0].cpu().numpy())

            # # Check pairs based on cosine similarity
            # correct_pairs += ((cosine_sim > cosine_similarity_threshold) & (label == 1)).sum().item()
            # correct_pairs += ((cosine_sim <= cosine_similarity_threshold) & (label == 0)).sum().item()
            # total_pairs += label.size(0)
            
            for i in range(12):
                val_epoch_dimensional_losses[f"dim_{i}"].append(val_feature_loss[:, i].mean().item())
        
        # Store the average dimensional loss for this epoch
        for i in range(12):
            val_feature_losses[f"dim_{i}"].append(np.mean(val_epoch_dimensional_losses[f"dim_{i}"]))
                
        # true_avg_val_sim = np.mean(true_pairs_val_similarity)
        # false_avg_val_sim = np.mean(false_pairs_val_similarity)

        print(f"Epoch {epoch + 1}/{num_epochs} - Validation Loss: {total_val_loss/len(test_dataloader)}")
        # print(f"Average True Matching Similarity (Validation): {true_avg_val_sim:.2f}")
        # print(f"Average False Matching Similarity (Validation): {false_avg_val_sim:.2f}")
        # print(f"Difference (Validation): {true_avg_val_sim - false_avg_val_sim:.2f}\n")
        # print(f"Validation Accuracy: {correct_pairs / total_pairs * 100:.2f}%")

# %%
model_name = model.__class__.__name__ + '.pth'
torch.save(model.state_dict(), 'result/' + model_name)

# %%
# Visualizing the losses
plt.figure(figsize=(6,4))
for i in range(12):
    plt.plot(feature_losses[f"dim_{i}"], label=f"Dimension {i}")
plt.legend()
plt.title("Dimension-wise Training Losses over Epochs")
plt.xlabel("Epochs")
plt.ylabel("Loss")
# Save the plot with a specific DPI
plt.savefig('pic/training_loss.png', dpi=300)  # 300 DPI is a common high-resolution setting
plt.show()

# %%
# Visualizing the losses
plt.figure(figsize=(6,4))
for i in range(12):
    plt.plot(val_feature_losses[f"dim_{i}"], label=f"Dimension {i}")
plt.legend()
plt.title("Dimension-wise Validation Losses over Epochs")
plt.xlabel("Epochs")
plt.ylabel("Loss")
# Save the plot with a specific DPI
plt.savefig('pic/val_loss.png', dpi=300)  # 300 DPI is a common high-resolution setting
plt.show()

# %%
#test by hand 
test_v = [1000, 0 ]
test_p = [0.5,0.5]
test_behavioral_embedding = behavioral_embedding(test_p, test_v)
test_behavioral_embedding[[0,1,2,3,4,10]] =  test_behavioral_embedding[[0,1,2,3,4,10]]/1000
test_text = option_prompt_generate(test_p, test_v)
print(f"test text : {test_text}")
model_name = 'text-embedding-ada-002'
tmp_embeddings = get_embeddings(test_text,model_name)
tmp_text_embeddings = tmp_embeddings.data[0].embedding
tmp_text_embeddings = torch.tensor(tmp_text_embeddings).to(device)
model.eval()
with torch.no_grad():
    tmp_text_shared_embedding = model(tmp_text_embeddings )

# %%
print(f"test behavioral embedding: {test_behavioral_embedding}")
print(f"test text shared embedding: {tmp_text_shared_embedding}")
